# %%
import itertools
import copy
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import pickle
import random
from sklearn.model_selection import train_test_split

# %%
import functions.plotting as NNplt
from functions.rnn_sequences import generate_sequences, convert_seq2inputs, inputs_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-d35ca7b04fc9> in <module>
#       1 import functions.plotting as NNplt
# ----> 2 from functions.rnn_sequences import generate_sequences, convert_seq2inputs, inputs_split
#
# ImportError: cannot import name 'inputs_split' from 'functions.rnn_sequences' (/Users/miahannah/compositional_learning_MW/functions/rnn_sequences.py)

# %%
def unique(list1):
    unique_list = []
    for x in list1:
        if x not in unique_list:
            unique_list.append(x)
    return unique_list

# %% [markdown]
# # RNN

# %%
class OneStepRNN(nn.Module):

    def __init__(self, input_size, output_size, hidden_size, num_layers):
        super(OneStepRNN, self).__init__()
        # Define parameters
        self.rnn = torch.nn.RNN(input_size=input_size,
                        hidden_size=hidden_size,
                        num_layers= num_layers,
                        batch_first=True)
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        # Define the layers
        self.input2hidden = nn.Linear(input_size + self.hidden_size, self.hidden_size)
        self.fc1tooutput = nn.Linear(self.hidden_size, output_size)

    def forward(self, x, hidden):
        combined = torch.cat((x, hidden), dim=0) ## dim = 1??
        self.hidden = nn.functional.relu(self.input2hidden(combined))
        self.output = self.fc1tooutput(self.hidden)
        #return self.output.view(-1,output_size), self.hidden
        return self.output, self.hidden

    def get_activations(self, x, hidden):
        self.forward(x, hidden)  # update the activations with the particular input
        return self.hidden, self.output #, self.fc1_activations

    def get_noise(self):
        return self.hidden_noise

    def initHidden(self):
        return torch.zeros(1, self.hidden_size)[0]


def train(sequence,label,model,optimizer,criterion):

    optimizer.zero_grad()
    #Read each cue in and keep hidden state for next cue
    hidden = model.initHidden()
    for i in range(len(sequence[0])):
        output, hidden = model.forward(sequence[0][i], hidden)
    #Compare final output to target
    loss = criterion(output,label)#.long())
    #Back-propagate
    loss.backward()
    optimizer.step()

    return output, loss.item()

def run(model, train_data, epochs):

    model.train()
    loss_history = []
    for epoch in range(epochs):
        lossTotal = 0
        for x,y in train_data:
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
        loss_history.append(lossTotal)

    print(f'loss: {round(lossTotal,1)} ')
    return loss_history

def run_acc(model, train_data, test_data, epochs):

    model.train()
    loss_history = []
    acc_history = []
    for epoch in range(epochs):
        lossTotal = 0
        for x,y in train_data:
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
        loss_history.append(lossTotal)
        acc = test_acc(model, test_data, hidden_size)
        acc_history.append(acc)

    print(f'loss: {round(lossTotal,1)} ')
    print(f'accuracy: {round(acc,2)} ')
    return loss_history, acc_history


def run_cvrmse(model, train_data, epochs):

    model.train()
    rmse_history = []
    for epoch in range(epochs):
        lossTotal = 0
        ylog = 0
        for x,y in train_data:
            ylog += y.mean().item()
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
        rmse = (lossTotal/len(train_data))**0.5 # root mean square error
        cvrmse = rmse/(ylog/len(train_data))
        rmse_history.append(cvrmse)

    print(f'cv rmse: {round(cvrmse,2)} ')
    return rmse_history


def test_model(model, testdata, hidden_size, verbose=False):
    model.eval()
    SSE = 0
    yvals = []
    for x,y in testdata:
        yvals.append(y.item())
        hidden = torch.zeros(1, hidden_size)[0]
        for step in x[0]:
            hidden, y_hat = model.get_activations(step,hidden)
        SE = (y.item() - y_hat.detach().item())**2 # squared error
        SSE += SE # sum of square error
    RMSE = (SSE/len(yvals))**0.5
    CV_RMSE = 100*RMSE/np.mean(yvals)
    
    return CV_RMSE

def test_acc(model, testdata, hidden_size, verbose = False):
    model.eval()
    correct = 0
    for x,y in testdata:
        hidden = torch.zeros(1, hidden_size)[0]
        for step in x[0]:
            hidden, y_hat = model.get_activations(step,hidden)
        correct += sum(torch.round(y) == torch.round(y_hat)).item()/len(y)
    acc = correct/len(testdata)
    
    if verbose:
        print('test accuracy: %f ' % (acc))

    return acc

# %% [markdown]
# # Experiments:
# 1 step pretraining (compare 1 step pretraining to 2)
#
# primitive op (work out how operations work)
#
# primitive cue (work out number corresponding to cue id)
#
# ...stages vs sentence trial structure

# %% [markdown]
# # 1 step pretraining

# %%
# Generate data

operators = ['+', '*']
input_ids = [2,3] 
init_values = [5,7]

# generate trial data
batchsize = 1
def generate_step_trials(len_seq, scale):
    seqs = generate_sequences(operators, input_ids, len_seq, cue_dict = False, init_values = init_values, rand = False)
    print(len(seqs))
    trainset, testset = train_test_split(seqs, test_size=1/4)
    train_inputs = convert_seq2inputs(trainset*scale, num_classes=13, seq_len=5)
    test_inputs = convert_seq2inputs(testset*scale, num_classes=13, seq_len=5)
    train_data = DataLoader(train_inputs, batch_size=batchsize, shuffle=True)
    test_data = DataLoader(test_inputs, batch_size=batchsize, shuffle=True)
    return train_data, test_data

    
# 1 step trials
train_data1, test_data1 = generate_step_trials(1, 16)

# 2 step trials
train_data2, test_data2 = generate_step_trials(2, 4)

# 3 step trials
train_data3, test_data3 = generate_step_trials(3, 1)

print('train 1: ', len(train_data1))
print('test 1: ', len(test_data1))
print('train 2: ', len(train_data2))
print('test 2: ', len(test_data2))
print('train 3: ', len(train_data3))
print('test 3: ', len(test_data3))

save_dir = 'results/step_pretraining/batchsize_' + str(batchsize) + '/'
print(save_dir)
# Out:
# 8
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-ed3c0fe61846> in <module>
#      19
#      20 # 1 step trials
# ---> 21 train_data1, test_data1 = generate_step_trials(1, 16)
#      22
#      23 # 2 step trials
#
# <ipython-input-3-ed3c0fe61846> in generate_step_trials(len_seq, scale)
#      11     print(len(seqs))
#      12     trainset, testset = train_test_split(seqs, test_size=1/4)
# ---> 13     train_inputs = convert_seq2inputs(trainset*scale, num_classes=13, seq_len=5)
#      14     test_inputs = convert_seq2inputs(testset*scale, num_classes=13, seq_len=5)
#      15     train_data = DataLoader(train_inputs, batch_size=batchsize, shuffle=True)
#
# ~/compositional_learning_MW/functions/rnn_sequences.py in convert_seq2inputs(sequences, seq_len, stages, cont_out, num_classes, primitive_type)
#     168     out = [sublist[-1] for sublist in sequences]
#     169
# --> 170     seqdata = SequenceData(seq, out, seq_len, stages, cont_out, primitive_type)
#     171
#     172     return seqdata
#
# ~/compositional_learning_MW/functions/rnn_sequences.py in __init__(self, data, labels, seq_len, stages, cont_out, primitive_type)
#     138     def __init__(self, data, labels, seq_len, stages, cont_out, primitive_type):
#     139
# --> 140         self.data = convert_seq2onehot(data, stages, primitive_type)
#     141         self.seq_len = seq_len
#     142         if cont_out:
#
# ~/compositional_learning_MW/functions/rnn_sequences.py in convert_seq2onehot(seq, stages, primitive_type, num_classes)
#     193                 op = torch.nn.functional.one_hot(op, num_classes=num_classes)
#     194                 if not primitive_type:
# --> 195                     inputcue = torch.tensor(convert_inputcue[t[1]])
#     196                     inputcue = torch.nn.functional.one_hot(inputcue, num_classes=num_classes)
#     197                 elif primitive_type == 'op':
#
# KeyError: 3

# %%
# Parameters

num_classes = 13
input_size = num_classes
output_size = batchsize
hidden_size = 20
num_layers = 1
learningRate = 0.0005
epochs = 600

# %%
# 2 step task

num_sims = 100
epochs = 200

losses12 = []
accs12 = []
for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss1, acc1 = run_acc(model, train_data1, test_data1, epochs)
    loss2, acc2 = run_acc(model, train_data2, test_data2, epochs)
    losses12.append(loss1+loss2)
    accs12.append(acc1+acc2)

losses2 = []
accs2 = []
for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss2, acc2 = run_acc(model, train_data2, test_data2, epochs)
    losses2.append(loss2)
    accs2.append(acc2)
# Out:
# ### rep 0  ###
# loss: 0.4
# accuracy: 0.0
# loss: 25.3
# accuracy: 0.62
# ### rep 1  ###
# loss: 0.0
# accuracy: 0.0
# loss: 29.3
# accuracy: 0.12
# ### rep 2  ###
# loss: 89.6
# accuracy: 0.0
# loss: 26.5
# accuracy: 0.25
# ### rep 3  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.9
# accuracy: 0.5
# ### rep 4  ###
# loss: 0.0
# accuracy: 0.0
# loss: 2.6
# accuracy: 0.12
# ### rep 5  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.1
# accuracy: 0.5
# ### rep 6  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.6
# accuracy: 0.5
# ### rep 7  ###
# loss: 0.0
# accuracy: 0.0
# loss: 5.0
# accuracy: 0.62
# ### rep 8  ###
# loss: 92.3
# accuracy: 0.0
# loss: 39.9
# accuracy: 0.12
# ### rep 9  ###
# loss: 0.0
# accuracy: 0.0
# loss: 28.0
# accuracy: 0.25
# ### rep 10  ###
# loss: 0.0
# accuracy: 0.0
# loss: 23.6
# accuracy: 0.5
# ### rep 11  ###
# loss: 92.8
# accuracy: 0.5
# loss: 5.3
# accuracy: 0.25
# ### rep 12  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.1
# accuracy: 0.62
# ### rep 13  ###
# loss: 23.9
# accuracy: 0.0
# loss: 34.1
# accuracy: 0.25
# ### rep 14  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.4
# accuracy: 0.38
# ### rep 15  ###
# loss: 0.0
# accuracy: 0.0
# loss: 208.3
# accuracy: 0.0
# ### rep 16  ###
# loss: 90.6
# accuracy: 0.0
# loss: 100.1
# accuracy: 0.0
# ### rep 17  ###
# loss: 92.4
# accuracy: 0.0
# loss: 132.8
# accuracy: 0.25
# ### rep 18  ###
# loss: 0.0
# accuracy: 0.0
# loss: 10.0
# accuracy: 0.12
# ### rep 19  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.0
# accuracy: 0.5
# ### rep 20  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.1
# accuracy: 0.5
# ### rep 21  ###
# loss: 0.0
# accuracy: 0.0
# loss: 109.1
# accuracy: 0.12
# ### rep 22  ###
# loss: 0.0
# accuracy: 0.0
# loss: 15.0
# accuracy: 0.5
# ### rep 23  ###
# loss: 90.2
# accuracy: 0.0
# loss: 8.5
# accuracy: 0.5
# ### rep 24  ###
# loss: 91.6
# accuracy: 0.0
# loss: 10.8
# accuracy: 0.38
# ### rep 25  ###
# loss: 89.7
# accuracy: 0.0
# loss: 2.2
# accuracy: 0.25
# ### rep 26  ###
# loss: 0.0
# accuracy: 0.0
# loss: 6.8
# accuracy: 0.5
# ### rep 27  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.0
# accuracy: 0.5
# ### rep 28  ###
# loss: 93.5
# accuracy: 0.0
# loss: 336.7
# accuracy: 0.12
# ### rep 29  ###
# loss: 0.0
# accuracy: 0.0
# loss: 33.5
# accuracy: 0.12
# ### rep 30  ###
# loss: 0.0
# accuracy: 0.0
# loss: 10.1
# accuracy: 0.0
# ### rep 31  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.4
# accuracy: 0.0
# ### rep 32  ###
# loss: 0.1
# accuracy: 0.0
# loss: 2.9
# accuracy: 0.5
# ### rep 33  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.4
# accuracy: 0.12
# ### rep 34  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.6
# accuracy: 0.5
# ### rep 35  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.0
# accuracy: 0.5
# ### rep 36  ###
# loss: 0.0
# accuracy: 0.0
# loss: 7.8
# accuracy: 0.38
# ### rep 37  ###
# loss: 91.4
# accuracy: 0.5
# loss: 508.2
# accuracy: 0.0
# ### rep 38  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.6
# accuracy: 0.25
# ### rep 39  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.0
# accuracy: 0.25
# ### rep 40  ###
# loss: 0.0
# accuracy: 0.0
# loss: 142.7
# accuracy: 0.12
# ### rep 41  ###
# loss: 0.0
# accuracy: 0.0
# loss: 34.0
# accuracy: 0.38
# ### rep 42  ###
# loss: 1.0
# accuracy: 0.0
# loss: 6.7
# accuracy: 0.62
# ### rep 43  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.2
# accuracy: 0.5
# ### rep 44  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.8
# accuracy: 0.5
# ### rep 45  ###
# loss: 0.0
# accuracy: 0.0
# loss: 11.2
# accuracy: 0.5
# ### rep 46  ###
# loss: 0.0
# accuracy: 0.0
# loss: 2.9
# accuracy: 0.5
# ### rep 47  ###
# loss: 0.0
# accuracy: 0.0
# loss: 80.2
# accuracy: 0.12
# ### rep 48  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.7
# accuracy: 0.62
# ### rep 49  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.6
# accuracy: 0.38
# ### rep 50  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.5
# accuracy: 0.25
# ### rep 51  ###
# loss: 0.0
# accuracy: 0.0
# loss: 70.4
# accuracy: 0.0
# ### rep 52  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.4
# accuracy: 0.62
# ### rep 53  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.9
# accuracy: 0.5
# ### rep 54  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.7
# accuracy: 0.25
# ### rep 55  ###
# loss: 0.0
# accuracy: 0.0
# loss: 46.8
# accuracy: 0.25
# ### rep 56  ###
# loss: 0.0
# accuracy: 0.0
# loss: 17.7
# accuracy: 0.5
# ### rep 57  ###
# loss: 0.0
# accuracy: 0.0
# loss: 9.8
# accuracy: 0.25
# ### rep 58  ###
# loss: 0.0
# accuracy: 0.0
# loss: 2.5
# accuracy: 0.62
# ### rep 59  ###
# loss: 0.2
# accuracy: 0.0
# loss: 5.8
# accuracy: 0.5
# ### rep 60  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.8
# accuracy: 0.38
# ### rep 61  ###
# loss: 0.0
# accuracy: 0.0
# loss: 32.3
# accuracy: 0.38
# ### rep 62  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.3
# accuracy: 0.25
# ### rep 63  ###
# loss: 0.0
# accuracy: 0.0
# loss: 6.5
# accuracy: 0.5
# ### rep 64  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.5
# accuracy: 0.5
# ### rep 65  ###
# loss: 0.0
# accuracy: 0.0
# loss: 45.2
# accuracy: 0.12
# ### rep 66  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.5
# accuracy: 0.5
# ### rep 67  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.8
# accuracy: 0.38
# ### rep 68  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.2
# accuracy: 0.12
# ### rep 69  ###
# loss: 0.0
# accuracy: 0.0
# loss: 7.4
# accuracy: 0.38
# ### rep 70  ###
# loss: 0.0
# accuracy: 0.0
# loss: 20.5
# accuracy: 0.38
# ### rep 71  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.3
# accuracy: 0.62
# ### rep 72  ###
# loss: 89.1
# accuracy: 0.0
# loss: 10.4
# accuracy: 0.38
# ### rep 73  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.3
# accuracy: 0.75
# ### rep 74  ###
# loss: 91.8
# accuracy: 0.0
# loss: 496.1
# accuracy: 0.0
# ### rep 75  ###
# loss: 0.0
# accuracy: 0.0
# loss: 14.0
# accuracy: 0.38
# ### rep 76  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.0
# accuracy: 0.5
# ### rep 77  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.9
# accuracy: 0.5
# ### rep 78  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.9
# accuracy: 0.75
# ### rep 79  ###
# loss: 0.0
# accuracy: 0.0
# loss: 26.2
# accuracy: 0.38
# ### rep 80  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.3
# accuracy: 0.5
# ### rep 81  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.1
# accuracy: 0.62
# ### rep 82  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.0
# accuracy: 0.5
# ### rep 83  ###
# loss: 0.4
# accuracy: 0.0
# loss: 6.2
# accuracy: 0.75
# ### rep 84  ###
# loss: 0.0
# accuracy: 0.0
# loss: 9.9
# accuracy: 0.75
# ### rep 85  ###
# loss: 0.0
# accuracy: 0.0
# loss: 5.5
# accuracy: 0.38
# ### rep 86  ###
# loss: 0.0
# accuracy: 0.0
# loss: 23.1
# accuracy: 0.25
# ### rep 87  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.5
# accuracy: 0.5
# ### rep 88  ###
# loss: 0.0
# accuracy: 0.0
# loss: 32.5
# accuracy: 0.25
# ### rep 89  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.7
# accuracy: 0.38
# ### rep 90  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.9
# accuracy: 0.38
# ### rep 91  ###
# loss: 0.0
# accuracy: 0.0
# loss: 42.9
# accuracy: 0.62
# ### rep 92  ###
# loss: 0.0
# accuracy: 0.0
# loss: 7.1
# accuracy: 0.12
# ### rep 93  ###
# loss: 0.0
# accuracy: 0.0
# loss: 8.9
# accuracy: 0.38
# ### rep 94  ###
# loss: 0.0
# accuracy: 0.0
# loss: 12.0
# accuracy: 0.5
# ### rep 95  ###
# loss: 0.0
# accuracy: 0.0
# loss: 18.1
# accuracy: 0.38
# ### rep 96  ###
# loss: 0.0
# accuracy: 0.0
# loss: 9.8
# accuracy: 0.38
# ### rep 97  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.5
# accuracy: 0.38
# ### rep 98  ###
# loss: 0.0
# accuracy: 0.0
# loss: 57.1
# accuracy: 0.0
# ### rep 99  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.8
# accuracy: 0.25
# ### rep 0  ###
# loss: 2.5
# accuracy: 0.62
# ### rep 1  ###
# loss: 538.9
# accuracy: 0.0
# ### rep 2  ###
# loss: 0.9
# accuracy: 0.5
# ### rep 3  ###
# loss: 2.2
# accuracy: 0.5
# ### rep 4  ###
# loss: 0.2
# accuracy: 0.25
# ### rep 5  ###
# loss: 33.3
# accuracy: 0.12
# ### rep 6  ###
# loss: 5.4
# accuracy: 0.88
# ### rep 7  ###
# loss: 61.2
# accuracy: 0.38
# ### rep 8  ###
# loss: 4.0
# accuracy: 0.88
# ### rep 9  ###
# loss: 3.1
# accuracy: 0.5
# ### rep 10  ###
# loss: 2.4
# accuracy: 0.62
# ### rep 11  ###
# loss: 22.7
# accuracy: 0.5
# ### rep 12  ###
# loss: 1.1
# accuracy: 0.5
# ### rep 13  ###
# loss: 2.3
# accuracy: 0.25
# ### rep 14  ###
# loss: 0.9
# accuracy: 0.62
# ### rep 15  ###
# loss: 35.0
# accuracy: 0.38
# ### rep 16  ###
# loss: 583.7
# accuracy: 0.0
# ### rep 17  ###
# loss: 3.3
# accuracy: 0.38
# ### rep 18  ###
# loss: 17.0
# accuracy: 0.25
# ### rep 19  ###
# loss: 14.6
# accuracy: 0.75
# ### rep 20  ###
# loss: 2.4
# accuracy: 0.62
# ### rep 21  ###
# loss: 3.3
# accuracy: 0.5
# ### rep 22  ###
# loss: 1.1
# accuracy: 0.5
# ### rep 23  ###
# loss: 0.3
# accuracy: 0.5
# ### rep 24  ###
# loss: 516.6
# accuracy: 0.0
# ### rep 25  ###
# loss: 3.3
# accuracy: 0.62
# ### rep 26  ###
# loss: 0.4
# accuracy: 0.25
# ### rep 27  ###
# loss: 1.7
# accuracy: 0.5
# ### rep 28  ###
# loss: 7.3
# accuracy: 0.5
# ### rep 29  ###
# loss: 2.2
# accuracy: 0.62
# ### rep 30  ###
# loss: 2.4
# accuracy: 0.62
# ### rep 31  ###
# loss: 4.9
# accuracy: 0.38
# ### rep 32  ###
# loss: 1.1
# accuracy: 0.62
# ### rep 33  ###
# loss: 165.2
# accuracy: 0.0
# ### rep 34  ###
# loss: 0.9
# accuracy: 0.88
# ### rep 35  ###
# loss: 1.1
# accuracy: 0.75
# ### rep 36  ###
# loss: 10.8
# accuracy: 0.38
# ### rep 37  ###
# loss: 1.0
# accuracy: 0.5
# ### rep 38  ###
# loss: 7.9
# accuracy: 0.5
# ### rep 39  ###
# loss: 562.3
# accuracy: 0.0
# ### rep 40  ###
# loss: 1.7
# accuracy: 0.5
# ### rep 41  ###
# loss: 535.8
# accuracy: 0.12
# ### rep 42  ###
# loss: 35.9
# accuracy: 0.12
# ### rep 43  ###
# loss: 4.8
# accuracy: 0.5
# ### rep 44  ###
# loss: 1.9
# accuracy: 0.62
# ### rep 45  ###
# loss: 1.2
# accuracy: 0.75
# ### rep 46  ###
# loss: 16.1
# accuracy: 0.75
# ### rep 47  ###
# loss: 1.3
# accuracy: 0.5
# ### rep 48  ###
# loss: 3.1
# accuracy: 0.25
# ### rep 49  ###
# loss: 5.9
# accuracy: 0.5
# ### rep 50  ###
# loss: 0.4
# accuracy: 0.88
# ### rep 51  ###
# loss: 0.2
# accuracy: 0.75
# ### rep 52  ###
# loss: 63.1
# accuracy: 0.5
# ### rep 53  ###
# loss: 28.6
# accuracy: 0.5
# ### rep 54  ###
# loss: 302.6
# accuracy: 0.0
# ### rep 55  ###
# loss: 7.9
# accuracy: 0.62
# ### rep 56  ###
# loss: 1.1
# accuracy: 0.62
# ### rep 57  ###
# loss: 0.3
# accuracy: 0.25
# ### rep 58  ###
# loss: 2.3
# accuracy: 0.25
# ### rep 59  ###
# loss: 2.2
# accuracy: 0.0
# ### rep 60  ###
# loss: 0.7
# accuracy: 0.62
# ### rep 61  ###
# loss: 67.7
# accuracy: 0.0
# ### rep 62  ###
# loss: 20.0
# accuracy: 0.12
# ### rep 63  ###
# loss: 2.5
# accuracy: 0.12
# ### rep 64  ###
# loss: 10.2
# accuracy: 0.12
# ### rep 65  ###
# loss: 134.7
# accuracy: 0.62
# ### rep 66  ###
# loss: 21.8
# accuracy: 0.38
# ### rep 67  ###
# loss: 0.4
# accuracy: 0.5
# ### rep 68  ###
# loss: 229.5
# accuracy: 0.12
# ### rep 69  ###
# loss: 8.8
# accuracy: 0.38
# ### rep 70  ###
# loss: 1.8
# accuracy: 0.62
# ### rep 71  ###
# loss: 0.8
# accuracy: 0.75
# ### rep 72  ###
# loss: 45.7
# accuracy: 0.75
# ### rep 73  ###
# loss: 2.7
# accuracy: 0.75
# ### rep 74  ###
# loss: 0.7
# accuracy: 0.88
# ### rep 75  ###
# loss: 4.5
# accuracy: 0.12
# ### rep 76  ###
# loss: 13.0
# accuracy: 0.38
# ### rep 77  ###
# loss: 117.1
# accuracy: 0.5
# ### rep 78  ###
# loss: 0.9
# accuracy: 0.5
# ### rep 79  ###
# loss: 23.3
# accuracy: 0.62
# ### rep 80  ###
# loss: 2.0
# accuracy: 0.5
# ### rep 81  ###
# loss: 8.2
# accuracy: 0.5
# ### rep 82  ###
# loss: 189.6
# accuracy: 0.12
# ### rep 83  ###
# loss: 1.8
# accuracy: 0.38
# ### rep 84  ###
# loss: 14.9
# accuracy: 0.5
# ### rep 85  ###
# loss: 46.8
# accuracy: 0.62
# ### rep 86  ###
# loss: 10.7
# accuracy: 0.62
# ### rep 87  ###
# loss: 583.0
# accuracy: 0.0
# ### rep 88  ###
# loss: 13.5
# accuracy: 0.5
# ### rep 89  ###
# loss: 4.2
# accuracy: 0.75
# ### rep 90  ###
# loss: 0.2
# accuracy: 0.5
# ### rep 91  ###
# loss: 6.5
# accuracy: 0.25
# ### rep 92  ###
# loss: 46.4
# accuracy: 0.5
# ### rep 93  ###
# loss: 14.1
# accuracy: 0.38
# ### rep 94  ###
# loss: 10.5
# accuracy: 0.5
# ### rep 95  ###
# loss: 1.0
# accuracy: 0.75
# ### rep 96  ###
# loss: 22.4
# accuracy: 0.25
# ### rep 97  ###
# loss: 1.4
# accuracy: 0.5
# ### rep 98  ###
# loss: 415.7
# accuracy: 0.0
# ### rep 99  ###
# loss: 21.2
# accuracy: 0.5

# %%
# ## Save

fileObject = open(save_dir + 'losses_12', 'wb')
pickle.dump(losses2 , fileObject)
fileObject.close()

fileObject = open(save_dir + 'losses_2', 'wb')
pickle.dump(losses12 , fileObject)
fileObject.close()

# %%
losses_12 = np.array(losses12).T
losses_2 = np.array(losses2).T

NNplt.plotNN_losses([losses_12],\
                    labels = ['1 2 step pretrained'],\
                    colors = ['orange'])

NNplt.plotNN_shifted([losses_2],\
                     labels = ['2 step pretrained'],\
                     colors = ['green'],\
                     shift = 600)

# %%
# 3 step task

num_sims = 100
epochs = 600

losses123 = []
accs123 = []
for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss1, acc1 = run_acc(model, train_data1, test_data1, epochs)
    loss2, acc2 = run_acc(model, train_data2, test_data2, epochs)
    loss3, acc3 = run_acc(model, train_data3, test_data3, epochs)
    losses123.append(loss1+loss2+loss3)
    accs123.append(acc1+acc2+acc3)

losses23 = []
accs23 = []
for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss2, acc2 = run_acc(model, train_data2, test_data2, epochs)
    loss3, acc3 = run_acc(model, train_data3, test_data3, epochs)
    losses23.append(loss2+loss3)
    accs23.append(acc2+acc3)

losses3 = []
accs3 = []
for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss3, acc3 = run_acc(model, train_data3, test_data3, epochs)
    losses3.append(loss3)
    accs3.append(acc3)
# Out:
# ### rep 0  ###
# loss: 0.0
# accuracy: 0.0
# loss: 2.6
# accuracy: 0.12
# loss: 38.9
# accuracy: 0.25
# ### rep 1  ###
# loss: 0.0
# accuracy: 0.0
# loss: 6.0
# accuracy: 0.38
# loss: 249.1
# accuracy: 0.09
# ### rep 2  ###
# loss: 0.0
# accuracy: 0.0
# loss: 9.2
# accuracy: 0.5
# loss: 170.1
# accuracy: 0.25
# ### rep 3  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.6
# accuracy: 0.38
# loss: 24.9
# accuracy: 0.41
# ### rep 4  ###
# loss: 0.0
# accuracy: 0.0
# loss: 6.5
# accuracy: 0.12
# loss: 123.4
# accuracy: 0.16
# ### rep 5  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.7
# accuracy: 0.5
# loss: 50.3
# accuracy: 0.31
# ### rep 6  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.7
# accuracy: 0.62
# loss: 128.3
# accuracy: 0.34
# ### rep 7  ###
# loss: 0.1
# accuracy: 0.0
# loss: 11.6
# accuracy: 0.5
# loss: 103.4
# accuracy: 0.22
# ### rep 8  ###
# loss: 0.0
# accuracy: 0.0
# loss: 27.0
# accuracy: 0.12
# loss: 113.5
# accuracy: 0.25
# ### rep 9  ###
# loss: 0.0
# accuracy: 0.0
# loss: 8.6
# accuracy: 0.5
# loss: 141.6
# accuracy: 0.5
# ### rep 10  ###
# loss: 0.0
# accuracy: 0.0
# loss: 12.7
# accuracy: 0.38
# loss: 87.3
# accuracy: 0.25
# ### rep 11  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.1
# accuracy: 0.62
# loss: 209.0
# accuracy: 0.38
# ### rep 12  ###
# loss: 2.8
# accuracy: 0.0
# loss: 0.6
# accuracy: 0.25
# loss: 231.1
# accuracy: 0.12
# ### rep 13  ###
# loss: 0.0
# accuracy: 0.0
# loss: 20.9
# accuracy: 0.0
# loss: 245.2
# accuracy: 0.09
# ### rep 14  ###
# loss: 0.0
# accuracy: 0.0
# loss: 1.4
# accuracy: 0.12
# loss: 162.9
# accuracy: 0.19
# ### rep 15  ###
# loss: 91.1
# accuracy: 0.0
# loss: 6.7
# accuracy: 0.38
# loss: 63.2
# accuracy: 0.34
# ### rep 16  ###
# loss: 0.0
# accuracy: 0.0
# loss: 2.2
# accuracy: 0.5
# loss: 180.1
# accuracy: 0.09
# ### rep 17  ###
# loss: 91.0
# accuracy: 0.0
# loss: 1.0
# accuracy: 0.88
# loss: 49.5
# accuracy: 0.31
# ### rep 18  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.1
# accuracy: 0.38
# loss: 48.5
# accuracy: 0.47
# ### rep 19  ###
# loss: 0.0
# accuracy: 0.0
# loss: 9.1
# accuracy: 0.12
# loss: 1068.7
# accuracy: 0.06
# ### rep 20  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.4
# accuracy: 0.25
# loss: 79.5
# accuracy: 0.19
# ### rep 21  ###
# loss: 0.0
# accuracy: 0.0
# loss: 4.7
# accuracy: 0.5
# loss: 2504.6
# accuracy: 0.22
# ### rep 22  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.2
# accuracy: 0.5
# loss: 34.0
# accuracy: 0.53
# ### rep 23  ###
# loss: 0.0
# accuracy: 0.0
# loss: 9.0
# accuracy: 0.62
# loss: 67.4
# accuracy: 0.34
# ### rep 24  ###
# loss: 0.0
# accuracy: 0.0
# loss: 9.3
# accuracy: 0.62
# loss: 373.6
# accuracy: 0.09
# ### rep 25  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.5
# accuracy: 0.62
# loss: 34.3
# accuracy: 0.28
# ### rep 26  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.4
# accuracy: 0.75
# loss: 1208.3
# accuracy: 0.38
# ### rep 27  ###
# loss: 0.0
# accuracy: 0.0
# loss: 10.9
# accuracy: 0.38
# loss: 146.9
# accuracy: 0.41
# ### rep 28  ###
# loss: 0.0
# accuracy: 0.0
# loss: 2.9
# accuracy: 0.25
# loss: 294.2
# accuracy: 0.03
# ### rep 29  ###
# loss: 0.0
# accuracy: 0.0
# loss: 2.0
# accuracy: 0.62
# loss: 71.7
# accuracy: 0.47
# ### rep 30  ###
# loss: 0.0
# accuracy: 0.0
# loss: 17.0
# accuracy: 0.12
# loss: 412.1
# accuracy: 0.09
# ### rep 31  ###
# loss: 83.2
# accuracy: 0.0
# loss: 2.3
# accuracy: 0.5
# loss: 54.9
# accuracy: 0.25
# ### rep 32  ###
# loss: 0.0
# accuracy: 0.0
# loss: 10.6
# accuracy: 0.5
# loss: 152.9
# accuracy: 0.25
# ### rep 33  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.5
# accuracy: 0.12
# loss: 64.9
# accuracy: 0.34
# ### rep 34  ###
# loss: 0.4
# accuracy: 0.0
# loss: 4.3
# accuracy: 0.75
# loss: 105.9
# accuracy: 0.28
# ### rep 35  ###
# loss: 0.0
# accuracy: 0.0
# loss: 2.2
# accuracy: 0.0
# loss: 151.1
# accuracy: 0.19
# ### rep 36  ###
# loss: 0.0
# accuracy: 0.0
# loss: 3.4
# accuracy: 0.62
# loss: 153.7
# accuracy: 0.31
# ### rep 37  ###
# loss: 0.0
# accuracy: 0.0
# loss: 2.5
# accuracy: 0.5
# loss: 427.3
# accuracy: 0.41
# ### rep 38  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.1
# accuracy: 0.38
# loss: 125.4
# accuracy: 0.19
# ### rep 39  ###
# loss: 0.0
# accuracy: 0.0
# loss: 9.3
# accuracy: 0.38
# loss: 41.3
# accuracy: 0.53
# ### rep 40  ###
# loss: 0.0
# accuracy: 0.0
# loss: 0.6
# accuracy: 0.25
# loss: 214.8
# accuracy: 0.09
# ### rep 41  ###
# loss: 0.0
# accuracy: 0.0
# loss: 16.3
# accuracy: 0.38
# loss: 39.2
# accuracy: 0.28
# ### rep 42  ###
# loss: 97.3
# accuracy: 0.5
# loss: 7.2
# accuracy: 0.5

# %%
# ## Save

fileObject = open(save_dir + 'losses_123', 'wb')
pickle.dump(losses123 , fileObject)
fileObject.close()

fileObject = open(save_dir + 'losses_23', 'wb')
pickle.dump(losses23 , fileObject)
fileObject.close()

fileObject = open(save_dir + 'losses_3', 'wb')
pickle.dump(losses3 , fileObject)
fileObject.close()

# %%
losses_123 = np.array(losses123).T
losses_23 = np.array(losses23).T
losses_3 = np.array(losses3).T

NNplt.plotNN_losses([losses_123],\
                    labels = ['1 & 2 step pretrained'],\
                    colors = ['orange'])

NNplt.plotNN_shifted([losses_23],\
                     labels = ['2 step pretrained'],\
                     colors = ['green'],\
                     shift = 600)

NNplt.plotNN_shifted([losses_3],\
                     labels = ['random'],\
                     colors = ['blue'],\
                     shift = 1200)

# %% [markdown]
# # Primitive Cue

# %%
# Generate data

operators = ['+', '*']
input_ids = [2,3,5,7] 
init_values = [2,3,6]

len_seq = 1
scale=64
batchsize=16
seqs = generate_sequences(operators, input_ids, len_seq, cue_dict = False, init_values = init_values, rand = False)
trainset, testset = train_test_split(seqs, test_size=1/6)
train_inputs = convert_seq2inputs(trainset*scale, num_classes=13, seq_len=3, primitive_type = 'op')
test_inputs = convert_seq2inputs(testset*scale, num_classes=13, seq_len=3, primitive_type = 'op')
op_train_data = DataLoader(train_inputs, batch_size=batchsize, shuffle=True)
op_test_data = DataLoader(test_inputs, batch_size=batchsize, shuffle=True)

print('train cue: ', len(op_train_data))
print('test cue: ', len(op_test_data))
# Out:
# train cue:  80
# test cue:  16

# %%
# %%timeit -r1 -n1
epochs = 50
num_sims = 100

## train on task 1
losses_1step = []
for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss = run_cvrmse(model, train_data1, epochs)
    losses_1step.append(loss)
    test_acc_batch(model, test_data1, hidden_size)
    
# train on operation primitive then 1 step task
losses_op_1step = []
for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss1 = run_cvrmse(model, op_train_data, epochs)
    loss2 = run_cvrmse(model, train_data1, epochs)
    losses_op_1step.append(loss1+loss2)
    test_acc_batch(model, test_data1, hidden_size)
# Out:
# ### rep 0  ###
# cv rmse: 0.59
# test accuracy: 0.929688
# ### rep 1  ###
# cv rmse: 0.58
# test accuracy: 0.929688
# ### rep 2  ###
# cv rmse: 0.57
# test accuracy: 0.960938
# ### rep 3  ###
# cv rmse: 0.58
# test accuracy: 0.878906
# ### rep 4  ###
# cv rmse: 0.58
# test accuracy: 0.937500
# ### rep 5  ###
# cv rmse: 0.58
# test accuracy: 0.906250
# ### rep 6  ###
# cv rmse: 0.58
# test accuracy: 0.855469
# ### rep 7  ###
# cv rmse: 0.57
# test accuracy: 0.832031
# ### rep 8  ###
# cv rmse: 0.58
# test accuracy: 0.937500
# ### rep 9  ###
# cv rmse: 0.59
# test accuracy: 0.867188
# ### rep 10  ###
# cv rmse: 0.57
# test accuracy: 0.941406
# ### rep 11  ###
# cv rmse: 0.58
# test accuracy: 0.843750
# ### rep 12  ###
# cv rmse: 0.58
# test accuracy: 0.964844
# ### rep 13  ###
# cv rmse: 0.58
# test accuracy: 0.917969
# ### rep 14  ###
# cv rmse: 0.58
# test accuracy: 0.953125
# ### rep 15  ###
# cv rmse: 0.57
# test accuracy: 0.925781
# ### rep 16  ###
# cv rmse: 0.58
# test accuracy: 0.863281
# ### rep 17  ###
# cv rmse: 0.58
# test accuracy: 0.800781
# ### rep 18  ###
# cv rmse: 0.58
# test accuracy: 0.851562
# ### rep 19  ###
# cv rmse: 0.57
# test accuracy: 0.890625
# ### rep 20  ###
# cv rmse: 0.57
# test accuracy: 0.964844
# ### rep 21  ###
# cv rmse: 0.58
# test accuracy: 0.992188
# ### rep 22  ###
# cv rmse: 0.57
# test accuracy: 0.902344
# ### rep 23  ###
# cv rmse: 0.58
# test accuracy: 0.890625
# ### rep 24  ###
# cv rmse: 0.57
# test accuracy: 0.914062
# ### rep 25  ###
# cv rmse: 0.58
# test accuracy: 0.988281
# ### rep 26  ###
# cv rmse: 0.58
# test accuracy: 0.968750
# ### rep 27  ###
# cv rmse: 0.57
# test accuracy: 0.902344
# ### rep 28  ###
# cv rmse: 0.58
# test accuracy: 0.894531
# ### rep 29  ###
# cv rmse: 0.58
# test accuracy: 0.789062
# ### rep 30  ###
# cv rmse: 0.58
# test accuracy: 0.824219
# ### rep 31  ###
# cv rmse: 0.58
# test accuracy: 0.980469
# ### rep 32  ###
# cv rmse: 0.58
# test accuracy: 0.882812
# ### rep 33  ###
# cv rmse: 0.57
# test accuracy: 0.894531
# ### rep 34  ###
# cv rmse: 0.59
# test accuracy: 0.914062
# ### rep 35  ###
# cv rmse: 0.57
# test accuracy: 0.980469
# ### rep 36  ###
# cv rmse: 0.58
# test accuracy: 0.996094
# ### rep 37  ###
# cv rmse: 0.58
# test accuracy: 0.976562
# ### rep 38  ###
# cv rmse: 0.58
# test accuracy: 0.902344
# ### rep 39  ###
# cv rmse: 0.58
# test accuracy: 0.957031
# ### rep 40  ###
# cv rmse: 0.58
# test accuracy: 0.957031
# ### rep 41  ###
# cv rmse: 0.57
# test accuracy: 0.867188
# ### rep 42  ###
# cv rmse: 0.58
# test accuracy: 0.980469
# ### rep 43  ###
# cv rmse: 0.58
# test accuracy: 0.929688
# ### rep 44  ###
# cv rmse: 0.58
# test accuracy: 0.902344
# ### rep 45  ###
# cv rmse: 0.57
# test accuracy: 0.992188
# ### rep 46  ###
# cv rmse: 0.58
# test accuracy: 0.976562
# ### rep 47  ###
# cv rmse: 0.59
# test accuracy: 1.000000
# ### rep 48  ###
# cv rmse: 0.57
# test accuracy: 0.878906
# ### rep 49  ###
# cv rmse: 0.58
# test accuracy: 0.859375
# ### rep 50  ###
# cv rmse: 0.59
# test accuracy: 0.953125
# ### rep 51  ###
# cv rmse: 0.58
# test accuracy: 0.906250
# ### rep 52  ###
# cv rmse: 0.58
# test accuracy: 0.886719
# ### rep 53  ###
# cv rmse: 0.57
# test accuracy: 0.914062
# ### rep 54  ###
# cv rmse: 0.58
# test accuracy: 0.980469
# ### rep 55  ###
# cv rmse: 0.59
# test accuracy: 0.976562
# ### rep 56  ###
# cv rmse: 0.56
# test accuracy: 0.863281
# ### rep 57  ###
# cv rmse: 0.58
# test accuracy: 0.871094
# ### rep 58  ###
# cv rmse: 0.57
# test accuracy: 0.851562
# ### rep 59  ###
# cv rmse: 0.58
# test accuracy: 0.878906
# ### rep 60  ###
# cv rmse: 0.58
# test accuracy: 0.851562
# ### rep 61  ###
# cv rmse: 0.58
# test accuracy: 0.957031
# ### rep 62  ###
# cv rmse: 0.58
# test accuracy: 0.863281
# ### rep 63  ###
# cv rmse: 0.58
# test accuracy: 0.867188
# ### rep 64  ###
# cv rmse: 0.58
# test accuracy: 0.917969
# ### rep 65  ###
# cv rmse: 0.58
# test accuracy: 0.902344
# ### rep 66  ###
# cv rmse: 0.58
# test accuracy: 0.968750
# ### rep 67  ###
# cv rmse: 0.58
# test accuracy: 0.968750
# ### rep 68  ###
# cv rmse: 0.58
# test accuracy: 0.875000
# ### rep 69  ###
# cv rmse: 0.58
# test accuracy: 0.960938
# ### rep 70  ###
# cv rmse: 0.57
# test accuracy: 0.953125
# ### rep 71  ###
# cv rmse: 0.58
# test accuracy: 0.878906
# ### rep 72  ###
# cv rmse: 0.58
# test accuracy: 0.875000
# ### rep 73  ###
# cv rmse: 0.58
# test accuracy: 0.976562
# ### rep 74  ###
# cv rmse: 0.57
# test accuracy: 0.972656
# ### rep 75  ###
# cv rmse: 0.58
# test accuracy: 0.937500
# ### rep 76  ###
# cv rmse: 0.57
# test accuracy: 0.910156
# ### rep 77  ###
# cv rmse: 0.59
# test accuracy: 0.890625
# ### rep 78  ###
# cv rmse: 0.58
# test accuracy: 0.937500
# ### rep 79  ###
# cv rmse: 0.57
# test accuracy: 0.898438
# ### rep 80  ###
# cv rmse: 0.57
# test accuracy: 0.906250
# ### rep 81  ###
# cv rmse: 0.57
# test accuracy: 0.867188
# ### rep 82  ###
# cv rmse: 0.58
# test accuracy: 0.968750
# ### rep 83  ###
# cv rmse: 0.59
# test accuracy: 0.945312
# ### rep 84  ###
# cv rmse: 0.58
# test accuracy: 0.851562
# ### rep 85  ###
# cv rmse: 0.58
# test accuracy: 0.894531
# ### rep 86  ###
# cv rmse: 0.58
# test accuracy: 0.906250
# ### rep 87  ###
# cv rmse: 0.58
# test accuracy: 0.925781
# ### rep 88  ###
# cv rmse: 0.58
# test accuracy: 0.875000
# ### rep 89  ###
# cv rmse: 0.57
# test accuracy: 0.898438
# ### rep 90  ###
# cv rmse: 0.58
# test accuracy: 0.890625
# ### rep 91  ###
# cv rmse: 0.58
# test accuracy: 0.980469
# ### rep 92  ###
# cv rmse: 0.58
# test accuracy: 0.941406
# ### rep 93  ###
# cv rmse: 0.57
# test accuracy: 0.871094
# ### rep 94  ###
# cv rmse: 0.58
# test accuracy: 0.839844
# ### rep 95  ###
# cv rmse: 0.59
# test accuracy: 0.980469
# ### rep 96  ###
# cv rmse: 0.58
# test accuracy: 0.882812
# ### rep 97  ###
# cv rmse: 0.58
# test accuracy: 0.867188
# ### rep 98  ###
# cv rmse: 0.57
# test accuracy: 0.894531
# ### rep 99  ###
# cv rmse: 0.58
# test accuracy: 0.976562
# ### rep 0  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.890625
# ### rep 1  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.964844
# ### rep 2  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.851562
# ### rep 3  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.875000
# ### rep 4  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.804688
# ### rep 5  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.863281
# ### rep 6  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.855469
# ### rep 7  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.785156
# ### rep 8  ###
# cv rmse: 0.75
# cv rmse: 0.57
# test accuracy: 0.988281
# ### rep 9  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.968750
# ### rep 10  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.945312
# ### rep 11  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.968750
# ### rep 12  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.996094
# ### rep 13  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.964844
# ### rep 14  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.867188
# ### rep 15  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.933594
# ### rep 16  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.949219
# ### rep 17  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.968750
# ### rep 18  ###
# cv rmse: 0.75
# cv rmse: 0.59
# test accuracy: 0.976562
# ### rep 19  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.902344
# ### rep 20  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.859375
# ### rep 21  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.851562
# ### rep 22  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.871094
# ### rep 23  ###
# cv rmse: 0.74
# cv rmse: 0.56
# test accuracy: 0.968750
# ### rep 24  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.886719
# ### rep 25  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.839844
# ### rep 26  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.828125
# ### rep 27  ###
# cv rmse: 0.75
# cv rmse: 0.57
# test accuracy: 0.867188
# ### rep 28  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.824219
# ### rep 29  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.886719
# ### rep 30  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.851562
# ### rep 31  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.812500
# ### rep 32  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.933594
# ### rep 33  ###
# cv rmse: 0.75
# cv rmse: 0.57
# test accuracy: 0.933594
# ### rep 34  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.855469
# ### rep 35  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.890625
# ### rep 36  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.839844
# ### rep 37  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.828125
# ### rep 38  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.933594
# ### rep 39  ###
# cv rmse: 0.75
# cv rmse: 0.57
# test accuracy: 0.960938
# ### rep 40  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.878906
# ### rep 41  ###
# cv rmse: 0.73
# cv rmse: 0.58
# test accuracy: 0.781250
# ### rep 42  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.816406
# ### rep 43  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.882812
# ### rep 44  ###
# cv rmse: 0.75
# cv rmse: 0.57
# test accuracy: 0.917969
# ### rep 45  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.945312
# ### rep 46  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.984375
# ### rep 47  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.886719
# ### rep 48  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.968750
# ### rep 49  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.812500
# ### rep 50  ###
# cv rmse: 0.73
# cv rmse: 0.58
# test accuracy: 0.886719
# ### rep 51  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.859375
# ### rep 52  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.859375
# ### rep 53  ###
# cv rmse: 0.73
# cv rmse: 0.58
# test accuracy: 1.000000
# ### rep 54  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.957031
# ### rep 55  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.953125
# ### rep 56  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.871094
# ### rep 57  ###
# cv rmse: 0.75
# cv rmse: 0.57
# test accuracy: 0.925781
# ### rep 58  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.945312
# ### rep 59  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.917969
# ### rep 60  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.882812
# ### rep 61  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.937500
# ### rep 62  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.933594
# ### rep 63  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.828125
# ### rep 64  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.871094
# ### rep 65  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.988281
# ### rep 66  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.921875
# ### rep 67  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.921875
# ### rep 68  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.921875
# ### rep 69  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.828125
# ### rep 70  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.902344
# ### rep 71  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.914062
# ### rep 72  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.847656
# ### rep 73  ###
# cv rmse: 0.75
# cv rmse: 0.57
# test accuracy: 0.960938
# ### rep 74  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.886719
# ### rep 75  ###
# cv rmse: 0.75
# cv rmse: 0.59
# test accuracy: 0.890625
# ### rep 76  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.929688
# ### rep 77  ###
# cv rmse: 0.75
# cv rmse: 0.57
# test accuracy: 0.894531
# ### rep 78  ###
# cv rmse: 0.73
# cv rmse: 0.57
# test accuracy: 1.000000
# ### rep 79  ###
# cv rmse: 0.73
# cv rmse: 0.58
# test accuracy: 1.000000
# ### rep 80  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.878906
# ### rep 81  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.851562
# ### rep 82  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.863281
# ### rep 83  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.949219
# ### rep 84  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.910156
# ### rep 85  ###
# cv rmse: 0.73
# cv rmse: 0.58
# test accuracy: 0.929688
# ### rep 86  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.878906
# ### rep 87  ###
# cv rmse: 0.73
# cv rmse: 0.57
# test accuracy: 0.894531
# ### rep 88  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.894531
# ### rep 89  ###
# cv rmse: 0.73
# cv rmse: 0.58
# test accuracy: 0.878906
# ### rep 90  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.894531
# ### rep 91  ###
# cv rmse: 0.74
# cv rmse: 0.58
# test accuracy: 0.847656
# ### rep 92  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.867188
# ### rep 93  ###
# cv rmse: 0.73
# cv rmse: 0.57
# test accuracy: 0.906250
# ### rep 94  ###
# cv rmse: 0.74
# cv rmse: 0.57
# test accuracy: 0.843750
# ### rep 95  ###
# cv rmse: 0.75
# cv rmse: 0.59
# test accuracy: 0.843750
# ### rep 96  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.960938
# ### rep 97  ###
# cv rmse: 0.75
# cv rmse: 0.57
# test accuracy: 0.980469
# ### rep 98  ###
# cv rmse: 0.75
# cv rmse: 0.59
# test accuracy: 0.804688
# ### rep 99  ###
# cv rmse: 0.75
# cv rmse: 0.58
# test accuracy: 0.828125

# %%
losses_op_1 = np.array(losses_op_1step).T
losses_1 = np.array(losses_1step).T

NNplt.plotNN_losses([losses_op_1],\
                    labels = ['op prim pretrained'],\
                    colors = ['orange'])

NNplt.plotNN_shifted([losses_1],\
                     labels = ['random'],\
                     colors = ['blue'],\
                     shift = 50)

# %%
# try loses wu=ith du=iff vals

# %%
# plot 1 step op against 2 step
# do cue primitive

# %%
epochs = 40
num_sims = 3
learningRate = 0.001
## train on task 3
losses_3step = []
for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss = run(model, train_data3, epochs)
    losses_3step.append(loss)
    test_acc_batch(model, test_data3, hidden_size)
# Out:
# ### rep 0  ###
# loss: 6646720.5
# test accuracy: 0.988281
# ### rep 1  ###
# loss: 5675094.2
# test accuracy: 0.980469
# ### rep 2  ###
# loss: 6225988.0
# test accuracy: 0.964844

# %%
for l in losses_3step:
    plt.plot(l)

# %%
for l in losses_3step:
    plt.plot(l)
