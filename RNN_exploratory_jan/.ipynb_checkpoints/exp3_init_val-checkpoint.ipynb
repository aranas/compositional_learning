# %%
import itertools
import copy
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import pickle
import random
from sklearn.model_selection import train_test_split

# %%
import sys
import os
current = os.path.dirname(os.path.realpath('plotting.py'))
parent = os.path.dirname(current)
sys.path.append(parent)

# %%
import functions.plotting as NNplt
from functions.rnn_cryptic import generate_sequences, convert_seq2inputs, pad_select, pad_seqs

# %%
def unique(list1):
    unique_list = []
    for x in list1:
        if x not in unique_list:
            unique_list.append(x)
    return unique_list

# %% [markdown]
# # RNN

# %%
class OneStepRNN(nn.Module):

    def __init__(self, input_size, output_size, hidden_size, num_layers):
        super(OneStepRNN, self).__init__()
        # Define parameters
        self.rnn = torch.nn.RNN(input_size=input_size,
                        hidden_size=hidden_size,
                        num_layers= num_layers,
                        batch_first=True)
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        # Define the layers
        self.input2hidden = nn.Linear(input_size + self.hidden_size, self.hidden_size)
        self.fc1tooutput = nn.Linear(self.hidden_size, output_size)

    def forward(self, x, hidden):
        combined = torch.cat((x, hidden), dim=0) ## dim = 1??
        self.hidden = nn.functional.relu(self.input2hidden(combined))
        self.output = self.fc1tooutput(self.hidden)
        #return self.output.view(-1,output_size), self.hidden
        return self.output, self.hidden

    def get_activations(self, x, hidden):
        self.forward(x, hidden)  # update the activations with the particular input
        return self.hidden, self.output #, self.fc1_activations

    def get_noise(self):
        return self.hidden_noise

    def initHidden(self):
        return torch.zeros(1, self.hidden_size)[0]


def train(sequence,label,model,optimizer,criterion):

    optimizer.zero_grad()
    #Read each cue in and keep hidden state for next cue
    hidden = model.initHidden()
    for i in range(len(sequence[0])):
        output, hidden = model.forward(sequence[0][i], hidden)
    #Compare final output to target
    loss = criterion(output,label)#.long())
    #Back-propagate
    loss.backward()
    optimizer.step()

    return output, loss.item()

def run(model, train_data, epochs):

    model.train()
    loss_history = []
    for epoch in range(epochs):
        lossTotal = 0
        for x,y in train_data:
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
        loss_history.append(lossTotal)

    print(f'loss: {round(lossTotal,1)} ')
    return loss_history

def run_acc(model, train_data, test_data, epochs, verbose = False):

    model.train()
    loss_history = []
    acc_history = []
    for epoch in range(epochs):
        lossTotal = 0
        for i, (x,y) in enumerate(train_data):
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
            if (epoch%100 == 2):
                if i%50 == 0:
                    if verbose:
                        print('\n################\nepoch: ',epoch, '\n################\n')
                        print('output =. ' , output.detach().numpy())
                        print('label =. ' , y.detach().numpy())
                        test_acc(model, test_data, hidden_size, verbose = True)
        loss_history.append(lossTotal)
        acc = test_acc(model, test_data, hidden_size)
        acc_history.append(acc)

    print(f'loss: {round(lossTotal,1)} ')
    print(f'accuracy: {round(acc,2)} ')
    return loss_history, acc_history



def run_cvrmse(model, train_data, epochs):

    model.train()
    rmse_history = []
    for epoch in range(epochs):
        lossTotal = 0
        ylog = 0
        for x,y in train_data:
            ylog += y.mean().item()
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
        rmse = (lossTotal/len(train_data))**0.5 # root mean square error
        cvrmse = rmse/(ylog/len(train_data))
        rmse_history.append(cvrmse)

    print(f'cv rmse: {round(cvrmse,2)} ')
    return rmse_history


def test_model(model, testdata, hidden_size, verbose=False):
    model.eval()
    SSE = 0
    yvals = []
    for x,y in testdata:
        yvals.append(y.item())
        hidden = torch.zeros(1, hidden_size)[0]
        for step in x[0]:
            hidden, y_hat = model.get_activations(step,hidden)
        SE = (y.item() - y_hat.detach().item())**2 # squared error
        SSE += SE # sum of square error
    RMSE = (SSE/len(yvals))**0.5
    CV_RMSE = 100*RMSE/np.mean(yvals)
    
    return CV_RMSE

def test_acc(model, testdata, hidden_size, verbose = False):
    model.eval()
    correct = 0
    for x,y in testdata:
        hidden = torch.zeros(1, hidden_size)[0]
        for step in x[0]:
            hidden, y_hat = model.get_activations(step,hidden)
        correct += sum(torch.round(y) == torch.round(y_hat)).item()/len(y)
    acc = correct/len(testdata)
    
    if verbose:
        print('test accuracy: %f ' % (acc))

    return acc

def shuffle_weights(model):
    model2 = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    mod_dict = model.state_dict()
    shuffled_dict = {layer: shuffle_tensor(val) for layer, val in mod_dict.items()}
    model2.load_state_dict(shuffled_dict)
    return model2

def shuffle_tensor(t):
    idx = torch.randperm(t.nelement())
    t = t.view(-1)[idx].view(t.size())
    return t

# %% [markdown]
# # Experiments:
# 1 step pretraining (compare 1 step pretraining to 2)
#
# primitive op (work out how operations work)
#
# primitive cue (work out number corresponding to cue id)
#
# ...stages vs sentence trial structure

# %% [markdown]
# # 1 step pretraining

# %%
# Generate data
operators = ['+', '*']
input_ids = ['A', 'B']

batchsize = 1
scale = 2
hscale = int(scale/2)
len_seq = 1

# init vals 1
init_values = [1,7]
seqs1 = generate_sequences(operators, input_ids, len_seq, init_values = init_values, rand = False)
padseqs = pad_seqs(seqs1)
train_inputs = convert_seq2inputs(padseqs*scale, num_classes=13, seq_len=8)
train1 = DataLoader(train_inputs, batch_size=batchsize, shuffle=True)

# init vals 2
init_values = [5,6]
seqs2 = generate_sequences(operators, input_ids, len_seq, init_values = init_values, rand = False)
padseqs = pad_seqs(seqs2)
train_inputs = convert_seq2inputs(padseqs*scale, num_classes=13, seq_len=8)
train2 = DataLoader(train_inputs, batch_size=batchsize, shuffle=True)



print('train 1: ', len(train1))
print('train 2: ', len(train2))

savepath = 'results/primitives/init_vals_100123/'
print(save_dir)
# Out:
# train 1:  48
# train 2:  48
# results/cue_op_combo_090123/

# %%
num_classes = 14
input_size = num_classes
output_size = batchsize
hidden_size = 20
num_layers = 1
learningRate = 0.005

# %%
# train on init vals 1, then switch to 2

epochs = 500
num_sims = 100

one_shot_acc = []
losses=[]
accs = []
losses_rand = []
accs_rand = []

for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss1, acc1 = run_acc(model, train1, train1, epochs)
    
    acc_1shot = test_acc(model, train1, hidden_size, verbose = True)
    one_shot_acc.append(acc_1shot)
    print('----- 1 shot accuracy ------')
    
    model2 = shuffle_weights(model)
    
    loss2, acc2 = run_acc(model, train2, train2, epochs)
    losses.append(loss1+loss2)
    accs.append(acc1+acc2)
    
    optimizer = torch.optim.Adam(model2.parameters(), lr=learningRate)
    loss3, acc3 = run_acc(model2, train2, train2, epochs)
    losses_rand.append(loss3)
    accs_rand.append(acc3)
# Out:
# ### rep 0  ###
# loss: 20.0
# accuracy: 0.79
# test accuracy: 0.791667
# ----- 1 shot accuracy ------
# loss: 0.3
# accuracy: 1.0
# loss: 22.5
# accuracy: 0.71
# ### rep 1  ###
# loss: 3.7
# accuracy: 0.96
# test accuracy: 0.958333
# ----- 1 shot accuracy ------
# loss: 0.1
# accuracy: 1.0
# loss: 0.3
# accuracy: 1.0
# ### rep 2  ###
# loss: 0.8
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 8.3
# accuracy: 0.75
# loss: 0.1
# accuracy: 1.0
# ### rep 3  ###
# loss: 140.0
# accuracy: 0.54
# test accuracy: 0.541667
# ----- 1 shot accuracy ------
# loss: 2.1
# accuracy: 0.88
# loss: 60.8
# accuracy: 0.25
# ### rep 4  ###
# loss: 69.9
# accuracy: 0.33
# test accuracy: 0.333333
# ----- 1 shot accuracy ------
# loss: 0.3
# accuracy: 1.0
# loss: 1.1
# accuracy: 1.0
# ### rep 5  ###
# loss: 5.8
# accuracy: 0.75
# test accuracy: 0.750000
# ----- 1 shot accuracy ------
# loss: 2.4
# accuracy: 0.92
# loss: 3.1
# accuracy: 0.75
# ### rep 6  ###
# loss: 3.3
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.2
# accuracy: 1.0
# loss: 0.4
# accuracy: 1.0
# ### rep 7  ###
# loss: 0.8
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 3.1
# accuracy: 0.58
# loss: 0.2
# accuracy: 1.0
# ### rep 8  ###
# loss: 0.1
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.8
# accuracy: 1.0
# loss: 1.0
# accuracy: 1.0
# ### rep 9  ###
# loss: 1.1
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 2.8
# accuracy: 1.0
# loss: 1.2
# accuracy: 1.0
# ### rep 10  ###
# loss: 0.3
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.8
# accuracy: 1.0
# loss: 2.5
# accuracy: 1.0
# ### rep 11  ###
# loss: 26.4
# accuracy: 0.54
# test accuracy: 0.541667
# ----- 1 shot accuracy ------
# loss: 4.7
# accuracy: 0.71
# loss: 7.8
# accuracy: 0.38
# ### rep 12  ###
# loss: 0.8
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 40.5
# accuracy: 0.54
# loss: 1.4
# accuracy: 1.0
# ### rep 13  ###
# loss: 0.8
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 4.3
# accuracy: 0.92
# loss: 0.8
# accuracy: 1.0
# ### rep 14  ###
# loss: 4.9
# accuracy: 0.67
# test accuracy: 0.666667
# ----- 1 shot accuracy ------
# loss: 0.3
# accuracy: 1.0
# loss: 4.2
# accuracy: 0.92
# ### rep 15  ###
# loss: 1.7
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 1.7
# accuracy: 1.0
# loss: 1.2
# accuracy: 1.0
# ### rep 16  ###
# loss: 1.9
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 1.1
# accuracy: 0.88
# loss: 4.6
# accuracy: 0.92
# ### rep 17  ###
# loss: 0.6
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.9
# accuracy: 1.0
# loss: 0.0
# accuracy: 1.0
# ### rep 18  ###
# loss: 3.2
# accuracy: 0.96
# test accuracy: 0.958333
# ----- 1 shot accuracy ------
# loss: 3.0
# accuracy: 1.0
# loss: 0.2
# accuracy: 1.0
# ### rep 19  ###
# loss: 7.0
# accuracy: 0.96
# test accuracy: 0.958333
# ----- 1 shot accuracy ------
# loss: 6.6
# accuracy: 0.96
# loss: 0.5
# accuracy: 0.92
# ### rep 20  ###
# loss: 0.5
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 7.4
# accuracy: 1.0
# loss: 2.5
# accuracy: 0.92
# ### rep 21  ###
# loss: 1.5
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.8
# accuracy: 1.0
# loss: 32.7
# accuracy: 0.67
# ### rep 22  ###
# loss: 2.8
# accuracy: 0.75
# test accuracy: 0.750000
# ----- 1 shot accuracy ------
# loss: 1.2
# accuracy: 1.0
# loss: 1.5
# accuracy: 1.0
# ### rep 23  ###
# loss: 2.5
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.4
# accuracy: 1.0
# loss: 69.5
# accuracy: 0.38
# ### rep 24  ###
# loss: 0.3
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 3.9
# accuracy: 0.96
# loss: 3.1
# accuracy: 0.88
# ### rep 25  ###
# loss: 0.1
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 6.0
# accuracy: 1.0
# loss: 1.3
# accuracy: 1.0
# ### rep 26  ###
# loss: 0.1
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 2.8
# accuracy: 0.92
# loss: 6.3
# accuracy: 0.96
# ### rep 27  ###
# loss: 3.9
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 4.8
# accuracy: 0.83
# loss: 4.4
# accuracy: 1.0
# ### rep 28  ###
# loss: 0.1
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 1.0
# accuracy: 1.0
# loss: 14.1
# accuracy: 0.54
# ### rep 29  ###
# loss: 1.2
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 30.3
# accuracy: 0.25
# loss: 3.0
# accuracy: 1.0
# ### rep 30  ###
# loss: 4.9
# accuracy: 0.96
# test accuracy: 0.958333
# ----- 1 shot accuracy ------
# loss: 6.0
# accuracy: 0.88
# loss: 11.1
# accuracy: 0.92
# ### rep 31  ###
# loss: 0.4
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 1.1
# accuracy: 1.0
# loss: 2.2
# accuracy: 0.96
# ### rep 32  ###
# loss: 1.6
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.1
# accuracy: 1.0
# loss: 3.6
# accuracy: 0.92
# ### rep 33  ###
# loss: 10.1
# accuracy: 0.67
# test accuracy: 0.666667
# ----- 1 shot accuracy ------
# loss: 36.9
# accuracy: 0.12
# loss: 3.3
# accuracy: 0.96
# ### rep 34  ###
# loss: 0.5
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 5.1
# accuracy: 0.92
# loss: 2.9
# accuracy: 0.96
# ### rep 35  ###
# loss: 2.2
# accuracy: 0.96
# test accuracy: 0.958333
# ----- 1 shot accuracy ------
# loss: 9.0
# accuracy: 1.0
# loss: 4.1
# accuracy: 0.96
# ### rep 36  ###
# loss: 25.0
# accuracy: 0.83
# test accuracy: 0.833333
# ----- 1 shot accuracy ------
# loss: 3.4
# accuracy: 1.0
# loss: 8.6
# accuracy: 0.79
# ### rep 37  ###
# loss: 4.8
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 2.3
# accuracy: 0.79
# loss: 4.4
# accuracy: 0.96
# ### rep 38  ###
# loss: 3.8
# accuracy: 0.62
# test accuracy: 0.625000
# ----- 1 shot accuracy ------
# loss: 0.4
# accuracy: 1.0
# loss: 0.7
# accuracy: 1.0
# ### rep 39  ###
# loss: 0.9
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 1.9
# accuracy: 1.0
# loss: 1.0
# accuracy: 0.96
# ### rep 40  ###
# loss: 0.8
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 4.0
# accuracy: 1.0
# loss: 0.9
# accuracy: 1.0
# ### rep 41  ###
# loss: 0.0
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.2
# accuracy: 1.0
# loss: 28.1
# accuracy: 0.54
# ### rep 42  ###
# loss: 6.0
# accuracy: 0.75
# test accuracy: 0.750000
# ----- 1 shot accuracy ------
# loss: 0.6
# accuracy: 1.0
# loss: 4.2
# accuracy: 0.79
# ### rep 43  ###
# loss: 4.3
# accuracy: 0.92
# test accuracy: 0.916667
# ----- 1 shot accuracy ------
# loss: 2.0
# accuracy: 1.0
# loss: 2.1
# accuracy: 1.0
# ### rep 44  ###
# loss: 0.6
# accuracy: 0.96
# test accuracy: 0.958333
# ----- 1 shot accuracy ------
# loss: 0.5
# accuracy: 1.0
# loss: 0.6
# accuracy: 1.0
# ### rep 45  ###
# loss: 5.7
# accuracy: 0.83
# test accuracy: 0.833333
# ----- 1 shot accuracy ------
# loss: 2.8
# accuracy: 0.58
# loss: 1.7
# accuracy: 0.67
# ### rep 46  ###
# loss: 0.7
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 1.4
# accuracy: 1.0
# loss: 2.8
# accuracy: 1.0
# ### rep 47  ###
# loss: 59.1
# accuracy: 0.54
# test accuracy: 0.541667
# ----- 1 shot accuracy ------
# loss: 0.4
# accuracy: 1.0
# loss: 36.8
# accuracy: 0.42
# ### rep 48  ###
# loss: 9.3
# accuracy: 0.79
# test accuracy: 0.791667
# ----- 1 shot accuracy ------
# loss: 6.4
# accuracy: 0.92
# loss: 1.0
# accuracy: 0.92
# ### rep 49  ###
# loss: 105.5
# accuracy: 0.54
# test accuracy: 0.541667
# ----- 1 shot accuracy ------
# loss: 5.6
# accuracy: 0.92
# loss: 11.2
# accuracy: 0.58
# ### rep 50  ###
# loss: 1.1
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.2
# accuracy: 1.0
# loss: 0.3
# accuracy: 1.0
# ### rep 51  ###
# loss: 57.6
# accuracy: 0.79
# test accuracy: 0.791667
# ----- 1 shot accuracy ------
# loss: 0.6
# accuracy: 1.0
# loss: 0.3
# accuracy: 1.0
# ### rep 52  ###
# loss: 2.5
# accuracy: 0.92
# test accuracy: 0.916667
# ----- 1 shot accuracy ------
# loss: 51.0
# accuracy: 0.62
# loss: 0.3
# accuracy: 1.0
# ### rep 53  ###
# loss: 4.0
# accuracy: 0.96
# test accuracy: 0.958333
# ----- 1 shot accuracy ------
# loss: 0.5
# accuracy: 1.0
# loss: 1.3
# accuracy: 0.79
# ### rep 54  ###
# loss: 0.7
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.3
# accuracy: 1.0
# loss: 0.5
# accuracy: 0.96
# ### rep 55  ###
# loss: 2.0
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 5.6
# accuracy: 0.92
# loss: 29.4
# accuracy: 0.21
# ### rep 56  ###
# loss: 1.1
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 1.5
# accuracy: 1.0
# loss: 0.5
# accuracy: 1.0
# ### rep 57  ###
# loss: 0.2
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.0
# accuracy: 1.0
# loss: 1.3
# accuracy: 1.0
# ### rep 58  ###
# loss: 0.5
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 2.7
# accuracy: 0.92
# loss: 0.0
# accuracy: 1.0
# ### rep 59  ###
# loss: 1.6
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 1.0
# accuracy: 1.0
# loss: 49.5
# accuracy: 0.67
# ### rep 60  ###
# loss: 1.9
# accuracy: 0.67
# test accuracy: 0.666667
# ----- 1 shot accuracy ------
# loss: 4.5
# accuracy: 1.0
# loss: 0.1
# accuracy: 1.0
# ### rep 61  ###
# loss: 63.6
# accuracy: 0.79
# test accuracy: 0.791667
# ----- 1 shot accuracy ------
# loss: 1.1
# accuracy: 1.0
# loss: 4.8
# accuracy: 0.96
# ### rep 62  ###
# loss: 56.8
# accuracy: 0.71
# test accuracy: 0.708333
# ----- 1 shot accuracy ------
# loss: 1.0
# accuracy: 1.0
# loss: 0.6
# accuracy: 1.0
# ### rep 63  ###
# loss: 0.3
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 2.1
# accuracy: 1.0
# loss: 1.0
# accuracy: 1.0
# ### rep 64  ###
# loss: 1.0
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.6
# accuracy: 1.0
# loss: 6.9
# accuracy: 0.75
# ### rep 65  ###
# loss: 13.2
# accuracy: 0.92
# test accuracy: 0.916667
# ----- 1 shot accuracy ------
# loss: 1.8
# accuracy: 1.0
# loss: 0.3
# accuracy: 1.0
# ### rep 66  ###
# loss: 0.1
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.7
# accuracy: 1.0
# loss: 0.2
# accuracy: 1.0
# ### rep 67  ###
# loss: 0.3
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 4.1
# accuracy: 0.67
# loss: 1.7
# accuracy: 1.0
# ### rep 68  ###
# loss: 5.0
# accuracy: 0.83
# test accuracy: 0.833333
# ----- 1 shot accuracy ------
# loss: 0.9
# accuracy: 1.0
# loss: 1.3
# accuracy: 1.0
# ### rep 69  ###
# loss: 0.4
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 5.9
# accuracy: 0.88
# loss: 0.6
# accuracy: 1.0
# ### rep 70  ###
# loss: 8.2
# accuracy: 0.88
# test accuracy: 0.875000
# ----- 1 shot accuracy ------
# loss: 5.4
# accuracy: 0.62
# loss: 0.8
# accuracy: 1.0
# ### rep 71  ###
# loss: 2.2
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 1.3
# accuracy: 1.0
# loss: 14.2
# accuracy: 0.71
# ### rep 72  ###
# loss: 0.0
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 10.8
# accuracy: 0.96
# loss: 1.7
# accuracy: 1.0
# ### rep 73  ###
# loss: 0.4
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 33.5
# accuracy: 0.04
# loss: 0.5
# accuracy: 1.0
# ### rep 74  ###
# loss: 5.3
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.6
# accuracy: 1.0
# loss: 0.9
# accuracy: 1.0
# ### rep 75  ###
# loss: 1.4
# accuracy: 0.92
# test accuracy: 0.916667
# ----- 1 shot accuracy ------
# loss: 13.8
# accuracy: 0.96
# loss: 0.1
# accuracy: 1.0
# ### rep 76  ###
# loss: 5.9
# accuracy: 0.92
# test accuracy: 0.916667
# ----- 1 shot accuracy ------
# loss: 2.7
# accuracy: 0.96
# loss: 0.1
# accuracy: 1.0
# ### rep 77  ###
# loss: 8.2
# accuracy: 0.62
# test accuracy: 0.625000
# ----- 1 shot accuracy ------
# loss: 3.0
# accuracy: 0.88
# loss: 41.1
# accuracy: 0.71
# ### rep 78  ###
# loss: 0.4
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.2
# accuracy: 1.0
# loss: 1.4
# accuracy: 1.0
# ### rep 79  ###
# loss: 1.2
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.6
# accuracy: 1.0
# loss: 1.0
# accuracy: 1.0
# ### rep 80  ###
# loss: 7.4
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.2
# accuracy: 1.0
# loss: 1.0
# accuracy: 1.0
# ### rep 81  ###
# loss: 0.6
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 27.1
# accuracy: 0.58
# loss: 0.7
# accuracy: 1.0
# ### rep 82  ###
# loss: 23.1
# accuracy: 0.75
# test accuracy: 0.750000
# ----- 1 shot accuracy ------
# loss: 2.5
# accuracy: 1.0
# loss: 0.2
# accuracy: 1.0
# ### rep 83  ###
# loss: 0.9
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 2.6
# accuracy: 0.92
# loss: 0.3
# accuracy: 1.0
# ### rep 84  ###
# loss: 0.5
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 3.1
# accuracy: 0.79
# loss: 0.0
# accuracy: 1.0
# ### rep 85  ###
# loss: 0.5
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 9.9
# accuracy: 0.88
# loss: 10.1
# accuracy: 0.88
# ### rep 86  ###
# loss: 1.1
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 2.9
# accuracy: 1.0
# loss: 0.6
# accuracy: 1.0
# ### rep 87  ###
# loss: 20.0
# accuracy: 0.5
# test accuracy: 0.500000
# ----- 1 shot accuracy ------
# loss: 0.4
# accuracy: 1.0
# loss: 0.8
# accuracy: 1.0
# ### rep 88  ###
# loss: 1.0
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.2
# accuracy: 1.0
# loss: 13.1
# accuracy: 0.83
# ### rep 89  ###
# loss: 2.9
# accuracy: 0.92
# test accuracy: 0.916667
# ----- 1 shot accuracy ------
# loss: 1.2
# accuracy: 1.0
# loss: 43.2
# accuracy: 0.46
# ### rep 90  ###
# loss: 3.1
# accuracy: 0.79
# test accuracy: 0.791667
# ----- 1 shot accuracy ------
# loss: 0.5
# accuracy: 1.0
# loss: 7.3
# accuracy: 0.92
# ### rep 91  ###
# loss: 13.0
# accuracy: 0.88
# test accuracy: 0.875000
# ----- 1 shot accuracy ------
# loss: 5.5
# accuracy: 0.79
# loss: 6.6
# accuracy: 1.0
# ### rep 92  ###
# loss: 14.2
# accuracy: 0.83
# test accuracy: 0.833333
# ----- 1 shot accuracy ------
# loss: 0.3
# accuracy: 1.0
# loss: 3.5
# accuracy: 1.0
# ### rep 93  ###
# loss: 1.4
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 8.4
# accuracy: 1.0
# loss: 4.6
# accuracy: 0.75
# ### rep 94  ###
# loss: 2.2
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.9
# accuracy: 1.0
# loss: 0.1
# accuracy: 1.0
# ### rep 95  ###
# loss: 1.6
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 2.3
# accuracy: 1.0
# loss: 1.3
# accuracy: 1.0
# ### rep 96  ###
# loss: 0.2
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 0.2
# accuracy: 1.0
# loss: 2.5
# accuracy: 1.0
# ### rep 97  ###
# loss: 25.4
# accuracy: 0.83
# test accuracy: 0.833333
# ----- 1 shot accuracy ------
# loss: 0.6
# accuracy: 1.0
# loss: 1.0
# accuracy: 1.0
# ### rep 98  ###
# loss: 37.5
# accuracy: 0.83
# test accuracy: 0.833333
# ----- 1 shot accuracy ------
# loss: 1.2
# accuracy: 1.0
# loss: 1.1
# accuracy: 1.0
# ### rep 99  ###
# loss: 0.2
# accuracy: 1.0
# test accuracy: 1.000000
# ----- 1 shot accuracy ------
# loss: 8.4
# accuracy: 0.54
# loss: 7.0
# accuracy: 0.92

# %%
lr = np.array(losses).T
r = np.array(losses_rand).T

NNplt.plotNN_shifted([lr],\
                    labels = ['a trained'],\
                    colors = ['orange'],\
                    shift = 0)
NNplt.plotNN_shifted([r],\
                    labels = ['random'],\
                    colors = ['blue'],\
                    shift = 500)
plt.ylim(0,200)
# Out:
# (0.0, 200.0)

# %%
lr = np.array(accs).T
r = np.array(accs_rand).T

NNplt.plotNN_shifted([lr],\
                    labels = ['a trained'],\
                    colors = ['orange'],\
                    shift = 0)
NNplt.plotNN_shifted([r],\
                    labels = ['random'],\
                    colors = ['blue'],\
                    shift = 500)

# %%
# save
savepath ='../results/primitives/init_vals_100123/'
fileObject = open(savepath + 'loss_set1set2', 'wb')
pickle.dump(losses , fileObject)
fileObject.close()
fileObject = open(savepath + 'acc_set1set2', 'wb')
pickle.dump(accs , fileObject)
fileObject.close()

fileObject = open(savepath + 'loss_set2', 'wb')
pickle.dump(losses_rand , fileObject)
fileObject.close()
fileObject = open(savepath + 'acc_set2', 'wb')
pickle.dump(accs_rand , fileObject)
fileObject.close()

fileObject = open(savepath + 'acc_set2_1shot', 'wb')
pickle.dump(one_shot_acc, fileObject)
fileObject.close()
