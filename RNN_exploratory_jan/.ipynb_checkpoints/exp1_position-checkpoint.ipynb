# %%
import itertools
import copy
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import pickle
import random
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
import sys
import os
current = os.path.dirname(os.path.realpath('plotting.py'))
parent = os.path.dirname(current)
sys.path.append(parent)

# %%
import functions.plotting as NNplt
from functions.rnn_cryptic import generate_sequences, convert_seq2inputs, pad_select, pad_seqs

# %%
def unique(list1):
    unique_list = []
    for x in list1:
        if x not in unique_list:
            unique_list.append(x)
    return unique_list

# %% [markdown]
# # RNN

# %%
class OneStepRNN(nn.Module):

    def __init__(self, input_size, output_size, hidden_size, num_layers):
        super(OneStepRNN, self).__init__()
        # Define parameters
        self.rnn = torch.nn.RNN(input_size=input_size,
                        hidden_size=hidden_size,
                        num_layers= num_layers,
                        batch_first=True)
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        # Define the layers
        self.input2hidden = nn.Linear(input_size + self.hidden_size, self.hidden_size)
        self.fc1tooutput = nn.Linear(self.hidden_size, output_size)

    def forward(self, x, hidden):
        combined = torch.cat((x, hidden), dim=0) ## dim = 1??
        self.hidden = nn.functional.relu(self.input2hidden(combined))
        self.output = self.fc1tooutput(self.hidden)
        #return self.output.view(-1,output_size), self.hidden
        return self.output, self.hidden

    def get_activations(self, x, hidden):
        self.forward(x, hidden)  # update the activations with the particular input
        return self.hidden, self.output #, self.fc1_activations

    def get_noise(self):
        return self.hidden_noise

    def initHidden(self):
        return torch.zeros(1, self.hidden_size)[0]


def train(sequence,label,model,optimizer,criterion):

    optimizer.zero_grad()
    #Read each cue in and keep hidden state for next cue
    hidden = model.initHidden()
    for i in range(len(sequence[0])):
        output, hidden = model.forward(sequence[0][i], hidden)
    #Compare final output to target
    loss = criterion(output,label)#.long())
    #Back-propagate
    loss.backward()
    optimizer.step()

    return output, loss.item()

def run(model, train_data, epochs):

    model.train()
    loss_history = []
    for epoch in range(epochs):
        lossTotal = 0
        for x,y in train_data:
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
        loss_history.append(lossTotal)

    print(f'loss: {round(lossTotal,1)} ')
    return loss_history

def run_acc(model, train_data, test_data, epochs, verbose = False):

    model.train()
    loss_history = []
    acc_history = []
    for epoch in range(epochs):
        lossTotal = 0
        for i, (x,y) in enumerate(train_data):
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
            if (epoch%100 == 2):
                if i%50 == 0:
                    if verbose:
                        print('\n################\nepoch: ',epoch, '\n################\n')
                        print('output =. ' , output.detach().numpy())
                        print('label =. ' , y.detach().numpy())
                        test_acc(model, test_data, hidden_size, verbose = True)
        loss_history.append(lossTotal)
        acc = test_acc(model, test_data, hidden_size)
        acc_history.append(acc)

    print(f'loss: {round(lossTotal,1)} ')
    print(f'accuracy: {round(acc,2)} ')
    return loss_history, acc_history



def run_cvrmse(model, train_data, epochs):

    model.train()
    rmse_history = []
    for epoch in range(epochs):
        lossTotal = 0
        ylog = 0
        for x,y in train_data:
            ylog += y.mean().item()
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
        rmse = (lossTotal/len(train_data))**0.5 # root mean square error
        cvrmse = rmse/(ylog/len(train_data))
        rmse_history.append(cvrmse)

    print(f'cv rmse: {round(cvrmse,2)} ')
    return rmse_history


def test_model(model, testdata, hidden_size, verbose=False):
    model.eval()
    SSE = 0
    yvals = []
    for x,y in testdata:
        yvals.append(y.item())
        hidden = torch.zeros(1, hidden_size)[0]
        for step in x[0]:
            hidden, y_hat = model.get_activations(step,hidden)
        SE = (y.item() - y_hat.detach().item())**2 # squared error
        SSE += SE # sum of square error
    RMSE = (SSE/len(yvals))**0.5
    CV_RMSE = 100*RMSE/np.mean(yvals)
    
    return CV_RMSE

def test_acc(model, testdata, hidden_size, verbose = False):
    model.eval()
    correct = 0
    for x,y in testdata:
        hidden = torch.zeros(1, hidden_size)[0]
        for step in x[0]:
            hidden, y_hat = model.get_activations(step,hidden)
        correct += sum(torch.round(y) == torch.round(y_hat)).item()/len(y)
    acc = correct/len(testdata)
    
    if verbose:
        print('test accuracy: %f ' % (acc))

    return acc

def shuffle_weights(model):
    model2 = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    mod_dict = model.state_dict()
    shuffled_dict = {layer: shuffle_tensor(val) for layer, val in mod_dict.items()}
    model2.load_state_dict(shuffled_dict)
    return model2

def shuffle_tensor(t):
    idx = torch.randperm(t.nelement())
    t = t.view(-1)[idx].view(t.size())
    return t

# %% [markdown]
# # Experiments:
# 1 step pretraining (compare 1 step pretraining to 2)
#
# primitive op (work out how operations work)
#
# primitive cue (work out number corresponding to cue id)
#
# ...stages vs sentence trial structure

# %% [markdown]
# # 1 step pretraining

# %%
# Generate data

operators = ['+', '*']
input_ids = ['A', 'B'] # 2, 3
init_values = [5,7]

# generate trial data
batchsize = 1
scale = 1
#halfscale = int(scale/2)
len_seq = 1

## single position
seqs = generate_sequences(operators, input_ids, len_seq, init_values = init_values, rand = False)
padseqs1 = pad_select(seqs, [0])
train_inputs1 = convert_seq2inputs(padseqs1*scale, num_classes=13, seq_len=8)
train_data1 = DataLoader(train_inputs1, batch_size=batchsize, shuffle=True)

seqs = generate_sequences(operators, input_ids, len_seq, init_values = init_values, rand = False)
padseqs2 = pad_select(seqs, [1])
train_inputs2 = convert_seq2inputs(padseqs2*scale, num_classes=13, seq_len=8)
train_data2 = DataLoader(train_inputs2, batch_size=batchsize, shuffle=True)

seqs = generate_sequences(operators, input_ids, len_seq, init_values = init_values, rand = False)
padseqs3 = pad_select(seqs, [2])
train_inputs3 = convert_seq2inputs(padseqs3*scale, num_classes=13, seq_len=8)
train_data3 = DataLoader(train_inputs3, batch_size=batchsize, shuffle=True)

## train on two positions
train_inputs12 = convert_seq2inputs(padseqs1*scale*2 + padseqs2*scale*2, num_classes=13, seq_len=8)
train_data12 = DataLoader(train_inputs12, batch_size=batchsize, shuffle=True)

## train on two positions
len_seq=2
seqs = generate_sequences(operators, input_ids, len_seq, init_values = init_values, rand = False)
padseqs_2step = pad_select(seqs, [0,1])
train_inputs_2step = convert_seq2inputs(padseqs_2step, num_classes=13, seq_len=8)
train_2step = DataLoader(train_inputs_2step, batch_size=batchsize, shuffle=True)




print('train 1: ', len(train_data1))
print('train 12: ', len(train_data12))
print('train 2 step: ', len(train_2step))
save_dir = '../results/position_pretraining_100123/'
print(save_dir)
# Out:
# train 1:  8
# train 12:  32
# train 2 step:  32
# ../results/position_pretraining_100123/

# %%
padseqs3
# Out:
# [[5, ('X', 'X'), ('X', 'X'), ('+', 'A'), 7],
#  [5, ('X', 'X'), ('X', 'X'), ('*', 'A'), 10],
#  [5, ('X', 'X'), ('X', 'X'), ('+', 'B'), 8],
#  [5, ('X', 'X'), ('X', 'X'), ('*', 'B'), 15],
#  [7, ('X', 'X'), ('X', 'X'), ('+', 'A'), 9],
#  [7, ('X', 'X'), ('X', 'X'), ('*', 'A'), 14],
#  [7, ('X', 'X'), ('X', 'X'), ('+', 'B'), 10],
#  [7, ('X', 'X'), ('X', 'X'), ('*', 'B'), 21]]

# %%
figpath = '../figures/position_pretraining_100123/'

# %% [markdown]
# # Step pretraining

# %%
# train on 1 position

num_classes = 14
input_size = num_classes
output_size = batchsize
hidden_size = 20
num_layers = 1
learningRate = 0.005
epochs = 300

num_sims = 100

one_shot_acc = []
losses=[]
accs = []
losses_rand = []
accs_rand = []

for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss1, acc1 = run_acc(model, train_data1, train_data1, epochs)
    
    acc_1shot = test_acc(model, train_data3, hidden_size, verbose = True)
    one_shot_acc.append(acc_1shot)
    print('----- test on pos 2 ------')
    
    model2 = shuffle_weights(model)
    
    loss2, acc2 = run_acc(model, train_data3, train_data3, epochs)
    losses.append(loss1+loss2)
    accs.append(acc1+acc2)
    
    optimizer = torch.optim.Adam(model2.parameters(), lr=learningRate)
    loss3, acc3 = run_acc(model2, train_data3, train_data3, epochs)
    losses_rand.append(loss3)
    accs_rand.append(acc3)

# save 
savepath = '../results/position_pretraining_100123/'
fileObject = open(savepath + 'loss_1pos_1_3', 'wb')
pickle.dump(losses , fileObject)
fileObject.close()
fileObject = open(savepath + 'acc_1pos_1_3', 'wb')
pickle.dump(accs , fileObject)
fileObject.close()

fileObject = open(savepath + 'loss_1pos_3', 'wb')
pickle.dump(losses_rand , fileObject)
fileObject.close()
fileObject = open(savepath + 'acc_1pos_3', 'wb')
pickle.dump(accs_rand , fileObject)
fileObject.close()

fileObject = open(savepath + 'acc_1pos_1shot', 'wb')
pickle.dump(one_shot_acc, fileObject)
fileObject.close()
# Out:
# ### rep 0  ###
# loss: 15.5
# accuracy: 0.75
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 23.0
# accuracy: 0.5
# loss: 6.1
# accuracy: 0.88
# ### rep 1  ###
# loss: 5.6
# accuracy: 1.0
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 0.0
# accuracy: 1.0
# loss: 0.3
# accuracy: 1.0
# ### rep 2  ###
# loss: 0.3
# accuracy: 1.0
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 0.1
# accuracy: 1.0
# loss: 0.2
# accuracy: 1.0
# ### rep 3  ###
# loss: 63.9
# accuracy: 0.75
# test accuracy: 0.125000
# ----- test on pos 2 ------
# loss: 0.4
# accuracy: 1.0
# loss: 0.4
# accuracy: 1.0
# ### rep 4  ###
# loss: 10.2
# accuracy: 0.75
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 0.3
# accuracy: 1.0
# loss: 44.9
# accuracy: 0.38
# ### rep 5  ###
# loss: 161.2
# accuracy: 0.5
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 0.1
# accuracy: 1.0
# loss: 0.0
# accuracy: 1.0
# ### rep 6  ###
# loss: 0.0
# accuracy: 1.0
# ...

# %%
with open(savepath + 'loss_1pos_1_3', 'rb') as file:
    losses = pickle.load(file)
with open(savepath + 'acc_1pos_1_3', 'rb') as file:
    accs = pickle.load(file)
with open(savepath + 'loss_1pos_3', 'rb') as file:
    losses_rand = pickle.load(file)
with open(savepath + 'acc_1pos_3', 'rb') as file:
    accs_rand = pickle.load(file)
with open(savepath + 'acc_1pos_1shot', 'rb') as file:
    one_shot1 = pickle.load(file)

# %%
l = np.array(losses).T
a = np.array(accs).T
lr = np.array(losses_rand).T
ar = np.array(accs_rand).T

NNplt.plotNN_losses([l],\
                    labels = ['1 position pretrained'],\
                    colors = ['orange'])
NNplt.plotNN_shifted([lr],\
                    labels = ['random'],\
                    colors = ['blue'],\
                    shift = 300)
plt.title('One position pretraining (1 step task)')
plt.ylim(0,300)
plt.savefig(figpath+'loss_1pos_1step.png')

# %%
NNplt.plotNN_losses([a],\
                    labels = ['1 position pretrained'],\
                    colors = ['orange'])
NNplt.plotNN_shifted([ar],\
                    labels = ['random'],\
                    colors = ['blue'],\
                    shift = 300)
plt.title('One position pretraining (1 step task)')
plt.ylabel('accuracy')
plt.savefig(figpath+'acc_1pos_1step.png')

# %%
oneshot1 = np.array(accs)[:,300]
print(np.mean(oneshot1))
print(np.std(oneshot1))
print(stats.ttest_1samp(oneshot1, 0, alternative = 'greater'))

sns.histplot(oneshot1, bins = 6,kde = True)
plt.xlabel('accuracy')
plt.title('One shot accuracy: 1 position pretraining, 1 operation task')
plt.savefig(figpath+'1pos_1step_1shotacc.png')
# Out:
# 0.13125
# 0.16805412074685938

# %% [markdown]
# # Two positions (1 step)

# %%
# train on 2 positions
num_classes = 14
input_size = num_classes
output_size = batchsize
hidden_size = 20
num_layers = 1
learningRate = 0.005
epochs = 300

num_sims = 100

losses=[]
accs = []
losses_rand = []
accs_rand = []
for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss1, acc1 = run_acc(model, train_data12, train_data12, epochs)
    
    acc_1shot = test_acc(model, train_data3, hidden_size, verbose = True)
    one_shot_acc.append(acc_1shot)
    print('----- test on pos 2 ------')
    model2 = shuffle_weights(model)
    
    loss2, acc2 = run_acc(model, train_data3, train_data3, epochs)
    losses.append(loss1+loss2)
    accs.append(acc1+acc2)
    
    optimizer = torch.optim.Adam(model2.parameters(), lr=learningRate)
    loss3, acc3 = run_acc(model2, train_data3, train_data3, epochs)
    losses_rand.append(loss3)
    accs_rand.append(acc3)
    
    
  # save
fileObject = open(savepath + 'loss_2pos_12_3', 'wb')
pickle.dump(losses , fileObject)
fileObject.close()
fileObject = open(savepath + 'acc_2pos_12_23', 'wb')
pickle.dump(accs , fileObject)
fileObject.close()

fileObject = open(savepath + 'loss_2pos_3', 'wb')
pickle.dump(losses_rand , fileObject)
fileObject.close()
fileObject = open(savepath + 'acc_2pos_3', 'wb')
pickle.dump(accs_rand , fileObject)
fileObject.close()

fileObject = open(savepath + 'acc_2pos_1shot', 'wb')
pickle.dump(one_shot_acc, fileObject)
fileObject.close()

# %%
with open(savepath + 'loss_2pos_12_3', 'rb') as file:
    losses = pickle.load(file)
with open(savepath + 'acc_2pos_12_23', 'rb') as file:
    accs = pickle.load(file)
with open(savepath + 'loss_2pos_3', 'rb') as file:
    losses_rand = pickle.load(file)
with open(savepath + 'acc_2pos_3', 'rb') as file:
    accs_rand = pickle.load(file)
with open(savepath + 'acc_2pos_1shot', 'rb') as file:
    one_shot2 = pickle.load(file)

# %%
one_shot2 = np.array(accs)[:,300]

# %%
l = np.array(losses).T
a = np.array(accs).T
lr = np.array(losses_rand).T
ar = np.array(accs_rand).T

NNplt.plotNN_losses([l],\
                    labels = ['2 position pretrained'],\
                    colors = ['orange'])
NNplt.plotNN_shifted([lr],\
                    labels = ['random'],\
                    colors = ['blue'],\
                    shift = 300)
plt.title('Two position pretraining (1 step task)')
plt.ylim(0,100)
plt.savefig(figpath+'loss_2pos_1step.png')

# %%
NNplt.plotNN_losses([a],\
                    labels = ['2 position pretrained'],\
                    colors = ['orange'])
NNplt.plotNN_shifted([ar],\
                    labels = ['random'],\
                    colors = ['blue'],\
                    shift = 300)
plt.title('Two position pretraining (1 step task)')
plt.ylabel('accuracy')
plt.savefig(figpath + 'acc_2pos_1step.png')

# %%
stats.ttest_1samp(one_shot2, 0, alternative = 'greater')
# Out:
# Ttest_1sampResult(statistic=12.521845318062812, pvalue=1.9895297660267356e-22)

# %%
print(np.mean(one_shot2))
print(np.std(one_shot2))
print(stats.ttest_1samp(one_shot2, 0, alternative = 'greater'))

sns.histplot(one_shot2, bins = 6,kde = True)
plt.xlabel('accuracy')
plt.title('One shot accuracy: 2 position pretraining, 1 operation task')
plt.savefig(figpath+'2pos_1step_1shotacc.png')
# Out:
# 0.18125
# 0.14402148277253637
# Ttest_1sampResult(statistic=12.521845318062812, pvalue=1.9895297660267356e-22)

# %%
stats.ttest_ind(oneshot1, one_shot2)
# Out:
# Ttest_indResult(statistic=-2.247805947796065, pvalue=0.025691186324138828)

# %% [markdown]
# # round 2 with different class sizes
#
# train on 2 x  step, then 2 step

# %%
# train on 2 positions
num_classes = 14
input_size = num_classes
output_size = batchsize
hidden_size = 20
num_layers = 1
learningRate = 0.0005
epochs = 900

num_sims = 100

losses=[]
accs = []
losses_rand = []
accs_rand = []
for j in range(num_sims):
    print('### rep', j, ' ###')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss1, acc1 = run_acc(model, train_data12, train_data12, epochs)
    
    acc_1shot = test_acc(model, train_data_2step, hidden_size, verbose = True)
    one_shot_acc.append(acc_1shot)
    print('----- test on pos 2 ------')
    model2 = shuffle_weights(model)
    
    loss2, acc2 = run_acc(model, train_2step, train_2step, epochs)
    losses.append(loss1+loss2)
    accs.append(acc1+acc2)
    
    optimizer = torch.optim.Adam(model2.parameters(), lr=learningRate)
    loss3, acc3 = run_acc(model2, train_2step, train_2step, epochs)
    losses_rand.append(loss3)
    accs_rand.append(acc3)
    
# save
savepath = '../results/position_pretraining_100123/'
fileObject = open(savepath + 'loss_2pos_12_2step', 'wb')
pickle.dump(losses , fileObject)
fileObject.close()
fileObject = open(savepath + 'acc_2pos_12_2step', 'wb')
pickle.dump(accs , fileObject)
fileObject.close()

fileObject = open(savepath + 'loss_2pos_2step', 'wb')
pickle.dump(losses_rand , fileObject)
fileObject.close()
fileObject = open(savepath + 'acc_2pos_2step', 'wb')
pickle.dump(accs_rand , fileObject)
fileObject.close()

fileObject = open(savepath + 'acc_2pos_2step_1shot', 'wb')
pickle.dump(one_shot_acc, fileObject)
fileObject.close()
# Out:
# ### rep 0  ###
# loss: 0.2
# accuracy: 1.0
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 1.6
# accuracy: 1.0
# loss: 0.8
# accuracy: 1.0
# ### rep 1  ###
# loss: 1.2
# accuracy: 1.0
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 3.4
# accuracy: 0.97
# loss: 0.3
# accuracy: 1.0
# ### rep 2  ###
# loss: 0.5
# accuracy: 0.81
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 22.8
# accuracy: 0.5
# loss: 106.7
# accuracy: 0.16
# ### rep 3  ###
# loss: 0.8
# accuracy: 1.0
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 6.6
# accuracy: 0.44
# loss: 3.1
# accuracy: 0.62
# ### rep 4  ###
# loss: 1.0
# accuracy: 1.0
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 5.5
# accuracy: 0.91
# loss: 0.7
# accuracy: 1.0
# ### rep 5  ###
# loss: 0.6
# accuracy: 1.0
# test accuracy: 0.000000
# ----- test on pos 2 ------
# loss: 0.8
# accuracy: 1.0
# loss: 10.0
# accuracy: 0.84
# ### rep 6  ###
# loss: 0.4
# accuracy: 1.0
# ...

# %%
savepath = '../results/position_pretraining_100123/'
with open(savepath + 'loss_2pos_12_2step', 'rb') as file:
    losses = pickle.load(file)
with open(savepath + 'acc_2pos_12_2step', 'rb') as file:
    accs = pickle.load(file)
with open(savepath + 'loss_2pos_2step', 'rb') as file:
    losses_rand = pickle.load(file)
with open(savepath + 'acc_2pos_2step', 'rb') as file:
    accs_rand = pickle.load(file)
with open(savepath + 'acc_2pos_2step_1shot', 'rb') as file:
    one_shot2step = pickle.load(file)

# %%
l = np.array(losses).T
a = np.array(accs).T
lr = np.array(losses_rand).T
ar = np.array(accs_rand).T

NNplt.plotNN_losses([l],\
                    labels = ['1 step pretrained'],\
                    colors = ['orange'])
NNplt.plotNN_shifted([lr],\
                    labels = ['random'],\
                    colors = ['blue'],\
                    shift = 900)
plt.title('single position pretraining for 2 step task')
plt.ylim(0,700)
plt.savefig(figpath+'2step_loss.png')

# %%
NNplt.plotNN_losses([a],\
                    labels = ['1 step pretrained'],\
                    colors = ['orange'])
NNplt.plotNN_shifted([ar],\
                    labels = ['random'],\
                    colors = ['blue'],\
                    shift = 900)
plt.title('single position pretraining for 2 step task')
plt.ylabel('accuracy')
plt.savefig(figpath+'2step_acc.png')

# %%
import seaborn as sns
sns.histplot(one_shot2step, bins = 6,kde = True)
plt.xlabel('1 shot accuracy')
plt.savefig(figpath+'2step_1shotacc.png')

# %%
unique(one_shot2step)
# Out:
# [0.0, 0.125, 0.25, 0.375, 0.5, 0.625]

# %%
np.mean(one_shot2step)
# Out:
# 0.0859375

# %%
np.std(one_shot2step)
# Out:
# 0.13437547812032444

# %%
from scipy import stats

# %%
stats.ttest_1samp(one_shot2step, 0, alternative = 'greater')
# Out:
# Ttest_1sampResult(statistic=11.132277078612004, pvalue=1.161186335842203e-24)
