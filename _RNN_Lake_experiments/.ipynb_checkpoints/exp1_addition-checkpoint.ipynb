# %%
import itertools
import copy
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import pickle
import random
from sklearn.model_selection import train_test_split
import time
from joblib import Parallel, delayed
import pandas as pd
import sys
import os
import seaborn as sns 
current = os.path.dirname(os.path.realpath('plotting.py'))
parent = os.path.dirname(current)
sys.path.append(parent)
import functions.plotting as NNplt
from functions.rnn_cryptic import generate_sequences, convert_seq2inputs,\
                                  pad_seqs_2step, pad_seqs_1step, calculate_output
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/6y/z1h4y1t94jvb186qws4p3qq40000gn/T/ipykernel_66431/2755120424.py in <module>
#      19 sys.path.append(parent)
#      20 import functions.plotting as NNplt
# ---> 21 from functions.rnn_cryptic import generate_sequences, convert_seq2inputs,\
#      22                                   pad_seqs_2step, calculate_output, pad_seqs_1step
#
# ImportError: cannot import name 'pad_seqs_1step' from 'functions.rnn_cryptic' (/Users/miahannah/compositional_learning_MW/functions/rnn_cryptic.py)
# ########## rep 5 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.1
# ########## rep 0 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 4 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 6 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 1 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 7 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 2 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.2
# ########## rep 3 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 2.3

# %%
class OneStepRNN(nn.Module):

    def __init__(self, input_size, output_size, hidden_size, num_layers):
        super(OneStepRNN, self).__init__()
        # Define parameters
        self.rnn = torch.nn.RNN(input_size=input_size,
                        hidden_size=hidden_size,
                        num_layers= num_layers,
                        batch_first=True)
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        # Define the layers
        self.input2hidden = nn.Linear(input_size + self.hidden_size, self.hidden_size)
        self.fc1tooutput = nn.Linear(self.hidden_size, output_size)

    def forward(self, x, hidden):
        combined = torch.cat((x, hidden), dim=0) ## dim = 1??
        self.hidden = nn.functional.relu(self.input2hidden(combined))
        self.output = self.fc1tooutput(self.hidden)
        #return self.output.view(-1,output_size), self.hidden
        return self.output, self.hidden

    def get_activations(self, x, hidden):
        self.forward(x, hidden)  # update the activations with the particular input
        return self.hidden, self.output #, self.fc1_activations

    def get_noise(self):
        return self.hidden_noise

    def initHidden(self):
        return torch.zeros(1, self.hidden_size)[0]


def train(sequence,label,model,optimizer,criterion):
    model.train()
    optimizer.zero_grad()
    #Read each cue in and keep hidden state for next cue
    hidden = model.initHidden()
    batch_out = []
    for batchseq in sequence:
        for i in range(len(batchseq)):
            output, hidden = model.forward(batchseq[i], hidden)
        batch_out.append(output)
        #Compare final output to target
    batch_out = torch.cat(batch_out)
    loss = criterion(batch_out,label)#.long())

    #Back-propagate
    loss.backward()
    optimizer.step()

    return batch_out, loss.item()


def run(model, train_data, epochs):

    model.train()
    loss_history = []
    for epoch in range(epochs):
        lossTotal = 0
        for x,y in train_data:
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
        loss_history.append(lossTotal)

    print(f'loss: {round(lossTotal,1)} ')
    return loss_history

def run_acc(model,optimizer,criterion, train_data, test_data, epochs, verbose = False):
    
    loss_history = np.empty((0,1))
    all_accs = np.empty((0,len(test_data)))
    for epoch in range(epochs):
        if epoch%100 == 0:
            print('epoch: ', epoch)
        lossTotal = 0
        for i, (x,y) in enumerate(train_data):
            output, loss = train(x,y,model,optimizer,criterion)
            lossTotal += loss # add MSE -> sum of square errors 
            if (epoch%100 == 2):
                if i%50 == 0:
                    if verbose:
                        print('\n################\nepoch: ',epoch, '\n################\n')
                        print('output =. ' , output.detach().numpy())
                        print('label =. ' , y.detach().numpy())
                        test_acc(model, test_data, hidden_size, verbose = True)
        loss_history = np.vstack([loss_history, lossTotal])
        acc = test_acc(model, test_data, hidden_size)
        all_accs = np.vstack([all_accs,acc])

    print(f'loss: {round(lossTotal,1)} ')
    return loss_history, all_accs

def test_acc(model, testdata, hidden_size, verbose = False):
    model.eval()
    accs = np.empty((1, 0))
    for testset in testdata:
        batch_correct = []
        for x,y in testset:
            correct = 0
            for i in range(len(x)):
                hidden = torch.zeros(1, hidden_size)[0]
                for step in x[i]:
                    hidden, y_hat = model.get_activations(step,hidden)
                correct += sum(torch.round(y[i]) == torch.round(y_hat)).item()
            batch_correct.append(correct/len(y))
        acc = np.mean(batch_correct)
        accs = np.append(accs, [acc])
    if verbose:
        print('test accuracy: %f ' % (acc))
    return accs


def shuffle_weights(model):
    model2 = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    mod_dict = model.state_dict()
    shuffled_dict = {layer: shuffle_tensor(val) for layer, val in mod_dict.items()}
    model2.load_state_dict(shuffled_dict)
    return model2

def shuffle_tensor(t):
    idx = torch.randperm(t.nelement())
    t = t.view(-1)[idx].view(t.size())
    return t

def run_sim(i, train_trials, test_trials):
    print('########## rep', i, '#########')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss1, acc1 = run_acc(model,optimizer,criterion, train_trials, test_trials, epochs)
    return loss1, acc1, model

def run_sims(i, train_trials, test_trials):
    print('########## rep', i, '#########')
    model = OneStepRNN(input_size, output_size, hidden_size, num_layers)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learningRate)
    loss1, acc1 = run_acc(model,optimizer,criterion, train_trials[0], test_trials, epochs)
    loss2, acc2 = run_acc(model,optimizer,criterion, train_trials[1], test_trials, epochs)
    losses = np.vstack([loss1,loss2])
    accs = np.vstack([acc1,acc2])
    return losses, accs, model


def seq_acc(model, testset, hidden_size, rep = 10, verbose = False):
    
    train_inputs = convert_seq2inputs(testset, num_classes=num_classes, seq_len=5)
    testdata = DataLoader(train_inputs, batch_size=batchsize, shuffle=False)
    model.eval()
    trials = []
    accs = []
    for _ in range(rep):
        for j, (x,y) in enumerate(testdata):
            for i in range(len(x)):
                hidden = torch.zeros(1, hidden_size)[0]
                for step in x[i]:
                    hidden, y_hat = model.get_activations(step,hidden)
                correct = sum(torch.round(y[i]) == torch.round(y_hat)).item() 
                accs.append(float(correct))
                curr_trial = testset[j*len(x)+i].copy()
                trials.append([x for x in curr_trial if x!= ('X', 'X')])
#                 trials.append(curr_trial)
    
    df = pd.DataFrame({'trial':trials, 'acc':accs})
    df['trial'] = df['trial'].apply(str)
    df = df.groupby(['trial']).mean()
           
    return df 

# ----------
# plotting
# ----------

def plotNNs(loss_arrays, acc_arrays, labels, colors, title, shift = 0):

    fig, axs = plt.subplots(2, 1)
    loss_cols = ['blue', 'darkblue', 'black']
    for i, arr in enumerate(loss_arrays):
        x = np.arange(0,arr.shape[0],1) + shift
        mn = arr.mean(axis=1)
        errs = arr.std(axis=1)
        
        axs[0].plot(x, mn, label = 'loss', color = loss_cols[i])
        axs[0].fill_between(x, mn - errs, mn + errs, alpha = 0.3, facecolor = loss_cols[i])
    
    axs[0].set_xlabel('epoch')
    axs[0].set_ylabel('loss')
    axs[0].legend()
    
    for i, arr in enumerate(acc_arrays):
        x = np.arange(0,arr.shape[0],1) + shift
        mn = arr.mean(axis=1)
        errs = arr.std(axis=1)
        
        axs[1].plot(x, mn, label = labels[i], color = colors[i])
        axs[1].fill_between(x, mn - errs, mn + errs, alpha = 0.3, facecolor = colors[i])
    
    axs[1].set_xlabel('epoch')
    axs[1].set_ylabel('accuracy')
    axs[1].legend()

    fig.suptitle(title, fontsize=14)

# %%
# params

num_classes = 14
batchsize=1
# specs
input_size = num_classes
output_size = 1
num_layers = 1
hidden_size = 20
learningRate = 0.001

# %% [markdown]
# # Trigrams: Addition

# %%
def exp1(p, trainseqs, testseqs):
    t1 = time.time()
    
    for val in trainseqs:
            if val in testseqs:
                testseqs.remove(val)

    padtrain = p + pad_seqs_2step(trainseqs)
    train_inputs = convert_seq2inputs(padtrain, num_classes=num_classes, seq_len=5)
    trainset = DataLoader(train_inputs, batch_size=batchsize, shuffle=True)
    padtest = pad_seqs_2step(testseqs)
    test_inputs = convert_seq2inputs(padtest, num_classes=num_classes, seq_len=5)
    testset = DataLoader(test_inputs, batch_size=batchsize, shuffle=True)
    
    # run
    t1 = time.time()
    num_sims = 8
    epochs = 500
    res = Parallel(n_jobs = -1)(delayed(run_sim)(i, trainset, [trainset, testset]) for i in range(num_sims))

    # format results
    losses = np.hstack([r[0] for r in res])
    acc_train = np.array([r[1][:,0] for r in res]).T
    acc_test = np.array([r[1][:,1] for r in res]).T
    models = [r[2] for r in res]

    # calculate test accuracy on each trial type
    dfs=[]
    for mod in models:
        dfs.append(seq_acc(mod, padtest, hidden_size, rep = 100, verbose = False))
    df = pd.concat(dfs, axis=1)
    print(df.apply(np.mean, axis=1).sort_values(ascending = False))  
    
    # plot
    plotNNs([losses], [acc_train, acc_test], ['train', 'test'], ['red', 'green'], '')
    
    t2 = time.time()
    print('time: ', (t2-t1)/60)
    return losses, acc_train, acc_test, dfs, models

# %%
def exp1_pretrain(trainseqs1, trainseqs2, testseqs):
    t1 = time.time()
    
    for val in trainseqs:
            if val in testseqs:
                testseqs.remove(val)
    
    padtrain1 = trainseqs1
    train_inputs = convert_seq2inputs(padtrain1, num_classes=num_classes, seq_len=5)
    trainset1 = DataLoader(train_inputs, batch_size=batchsize, shuffle=True)            
    padtrain2 = pad_seqs_2step(trainseqs2)
    train_inputs = convert_seq2inputs(padtrain2, num_classes=num_classes, seq_len=5)
    trainset2 = DataLoader(train_inputs, batch_size=batchsize, shuffle=True)
    padtest = pad_seqs_2step(testseqs)
    test_inputs = convert_seq2inputs(padtest, num_classes=num_classes, seq_len=5)
    testset = DataLoader(test_inputs, batch_size=batchsize, shuffle=True)
    
    # run
    t1 = time.time()
    num_sims = 8
    epochs = 500
    res = Parallel(n_jobs = -1)(delayed(run_sims)(i, [trainset1, trainset2], [trainset2, testset]) for i in range(num_sims))

    # format results
    losses = np.hstack([r[0] for r in res])
    acc_train = np.array([r[1][:,0] for r in res]).T
    acc_test = np.array([r[1][:,1] for r in res]).T
    models = [r[2] for r in res]

    # calculate test accuracy on each trial type
    dfs=[]
    for mod in models:
        dfs.append(seq_acc(mod, padtest, hidden_size, rep = 100, verbose = False))
    df = pd.concat(dfs, axis=1)
    print(df.apply(np.mean, axis=1).sort_values(ascending = False))  
    
    # plot
    plotNNs([losses], [acc_train, acc_test], ['train', 'test'], ['red', 'green'], '')
    
    t2 = time.time()
    print('time: ', (t2-t1)/60)
    return losses, acc_train, acc_test, dfs, models

# %% [markdown]
# ## 4 inputs
# ---

# %%
## exp 1 - 4 train inps ########### TEST: E

epochs = 1000

test_sym = 'E'

inits = ['A','B','C', 'D', 'E']

p = pad_seqs_1step(inits)
p
# p = [['A', ('+','X'), ('+','X'), 2],\
#      ['C', ('+','X'), ('+','X'), 5],\
#      ['B', ('+','X'), ('+','X'), 3],\
#      ['D', ('+','X'), ('+','X'), 7],\
#      ['E', ('+','X'), ('+','X'), 1]
#     ]

# trainseqs = generate_sequences(['+'], ['A','B','C', 'D'], len_seq = 1, init_values = ['A','B', 'C',  'D'])
# testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B','C', 'D', 'E'])

# losses1, acc_train1, acc_test1, dfs1, models1 = exp1(p, trainseqs, testseqs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6y/z1h4y1t94jvb186qws4p3qq40000gn/T/ipykernel_66431/4014672437.py in <module>
#       7 inits = ['A','B','C', 'D', 'E']
#       8
# ----> 9 p = pad_seqs_1step(inits)
#      10 p
#      11 # p = [['A', ('+','X'), ('+','X'), 2],\
#
# NameError: name 'pad_seqs_1step' is not defined

# %%
pad_seqs_2step(trainseqs, ('+','X'))
# Out:
# [['A', ('+', 'A'), ('+', 'X'), 4],
#  ['A', ('+', 'X'), ('+', 'A'), 4],
#  ['A', ('+', 'B'), ('+', 'X'), 5],
#  ['A', ('+', 'X'), ('+', 'B'), 5],
#  ['A', ('+', 'C'), ('+', 'X'), 7],
#  ['A', ('+', 'X'), ('+', 'C'), 7],
#  ['A', ('+', 'D'), ('+', 'X'), 9],
#  ['A', ('+', 'X'), ('+', 'D'), 9],
#  ['B', ('+', 'A'), ('+', 'X'), 5],
#  ['B', ('+', 'X'), ('+', 'A'), 5],
#  ['B', ('+', 'B'), ('+', 'X'), 6],
#  ['B', ('+', 'X'), ('+', 'B'), 6],
#  ['B', ('+', 'C'), ('+', 'X'), 8],
#  ['B', ('+', 'X'), ('+', 'C'), 8],
#  ['B', ('+', 'D'), ('+', 'X'), 10],
#  ['B', ('+', 'X'), ('+', 'D'), 10],
#  ['C', ('+', 'A'), ('+', 'X'), 7],
#  ['C', ('+', 'X'), ('+', 'A'), 7],
#  ['C', ('+', 'B'), ('+', 'X'), 8],
#  ['C', ('+', 'X'), ('+', 'B'), 8],
#  ['C', ('+', 'C'), ('+', 'X'), 10],
#  ['C', ('+', 'X'), ('+', 'C'), 10],
#  ['C', ('+', 'D'), ('+', 'X'), 12],
#  ['C', ('+', 'X'), ('+', 'D'), 12],
#  ['D', ('+', 'A'), ('+', 'X'), 9],
#  ['D', ('+', 'X'), ('+', 'A'), 9],
#  ['D', ('+', 'B'), ('+', 'X'), 10],
#  ['D', ('+', 'X'), ('+', 'B'), 10],
#  ['D', ('+', 'C'), ('+', 'X'), 12],
#  ['D', ('+', 'X'), ('+', 'C'), 12],
#  ['D', ('+', 'D'), ('+', 'X'), 14],
#  ['D', ('+', 'X'), ('+', 'D'), 14]]

# %%
## exp 1 - 4 train inps ########### TEST: A

epochs = 1000

p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1]
    ]

trainseqs = generate_sequences(['+'], ['E','B','C', 'D'], len_seq = 1, init_values = ['E','B', 'C',  'D'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B','C', 'D', 'E'])

#losses2, acc_train2, acc_test2, dfs2, models2 = exp1(p, trainseqs, testseqs)

# %%
## exp 1 - 4 train inps ########### TEST: C

epochs = 1000

p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1]
    ]

trainseqs = generate_sequences(['+'], ['A','B', 'E', 'D'], len_seq = 1, init_values = ['A','B',  'E',  'D'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B','C', 'D', 'E'])

losses3, acc_train3, acc_test3, dfs3, models3 = exp1(p, trainseqs, testseqs)
# Out:
# trial
# ['C', ('+', 'A'), 7]     1.0000
# ['C', ('+', 'B'), 8]     1.0000
# ['C', ('+', 'D'), 12]    1.0000
# ['C', ('+', 'E'), 6]     1.0000
# ['D', ('+', 'C'), 12]    0.8750
# ['B', ('+', 'C'), 8]     0.8125
# ['C', ('+', 'C'), 10]    0.8125
# ['A', ('+', 'C'), 7]     0.7500
# ['E', ('+', 'C'), 6]     0.7500
# dtype: float64
# time:  1.4826526959737143

# %%
## exp 1 - 4 train inps ########### TEST: B

epochs = 1000

p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1]
    ]

trainseqs = generate_sequences(['+'], ['A','E','C', 'D'], len_seq = 1, init_values = ['A','E', 'C',  'D'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B','C', 'D', 'E'])

res1b = exp1(p, trainseqs, testseqs)
# Out:
# ########## rep 1 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.5
# ########## rep 7 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 2.1
# ########## rep 6 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.8
# ########## rep 3 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.1
# ########## rep 0 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 5 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.3
# ########## rep 2 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 4 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/6y/z1h4y1t94jvb186qws4p3qq40000gn/T/ipykernel_42728/1711299750.py in <module>
#      13 testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B','C', 'D', 'E'])
#      14
# ---> 15 res1b = exp1(p, trainseqs, testseqs)
#
# /var/folders/6y/z1h4y1t94jvb186qws4p3qq40000gn/T/ipykernel_42728/3695704772.py in exp1(p, trainseqs, testseqs)
#      28     dfs=[]
#      29     for mod in models:
# ---> 30         dfs.append(seq_acc(mod, padtest, hidden_size, rep = 100, verbose = False))
#      31     df = pd.concat(dfs, axis=1)
#      32     print(df.apply(np.mean, axis=1).sort_values(ascending = False))
#
# /var/folders/6y/z1h4y1t94jvb186qws4p3qq40000gn/T/ipykernel_42728/100140976.py in seq_acc(model, testset, hidden_size, rep, verbose)
#     155             for i in range(len(x)):
#     156                 hidden = torch.zeros(1, hidden_size)[0]
# --> 157                 for step in x[i]:
#     158                     hidden, y_hat = model.get_activations(step,hidden)
#     159                 correct = sum(torch.round(y[i]) == torch.round(y_hat)).item()
#
# KeyboardInterrupt:

# %%
## exp 1 - 4 train inps ########### TEST: D

epochs = 1000

p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1]
    ]

trainseqs = generate_sequences(['+'], ['A','B','C', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B','C', 'D', 'E'])

res1e = exp1(p, trainseqs, testseqs)
# Out:
# trial
# ['D', ('+', 'A'), 9]     0.9375
# ['D', ('+', 'E'), 8]     0.9375
# ['D', ('+', 'B'), 10]    0.8750
# ['D', ('+', 'C'), 12]    0.8750
# ['A', ('+', 'D'), 9]     0.0000
# ['B', ('+', 'D'), 10]    0.0000
# ['C', ('+', 'D'), 12]    0.0000
# ['D', ('+', 'D'), 14]    0.0000
# ['E', ('+', 'D'), 8]     0.0000
# dtype: float64
# time:  2.938058602809906

# %%
#exp2 - 5a train inps ########## TEST: F
epochs = 1000
p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

res5a = exp1_pretrain(p, trainseqs, testseqs)
# Out:
# trial
# ['A', ('+', 'F'), 6]     1.0000
# ['B', ('+', 'F'), 7]     1.0000
# ['C', ('+', 'F'), 9]     1.0000
# ['D', ('+', 'F'), 11]    1.0000
# ['E', ('+', 'F'), 5]     1.0000
# ['F', ('+', 'A'), 6]     0.5000
# ['F', ('+', 'B'), 7]     0.5000
# ['F', ('+', 'C'), 9]     0.5000
# ['F', ('+', 'D'), 11]    0.5000
# ['F', ('+', 'E'), 5]     0.5000
# ['F', ('+', 'F'), 8]     0.4375
# dtype: float64
# time:  2.77864640156428
# ########## rep 7 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.2
# ########## rep 6 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 1.5
# ########## rep 4 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 0 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.3
# ########## rep 5 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 1 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 3 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 2 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0

# %%
#exp2 - 5 train inps ########## TEST: F

p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

res4 = exp1(p, trainseqs, testseqs)
# Out:
# trial
# ['B', ('+', 'F'), 7]     1.0000
# ['C', ('+', 'F'), 9]     1.0000
# ['E', ('+', 'F'), 5]     1.0000
# ['F', ('+', 'A'), 6]     1.0000
# ['F', ('+', 'B'), 7]     1.0000
# ['F', ('+', 'C'), 9]     1.0000
# ['F', ('+', 'D'), 11]    1.0000
# ['F', ('+', 'E'), 5]     1.0000
# ['A', ('+', 'F'), 6]     0.9375
# ['D', ('+', 'F'), 11]    0.9375
# ['F', ('+', 'F'), 8]     0.9375
# dtype: float64
# time:  2.1248111486434937

# %%
trainseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

train_outs = [seq[-1] for seq in trainseqs]
test_outs = [seq[-1] for seq in testseqs]

sns.kdeplot(train_outs, fill=True, color="r")
sns.kdeplot(test_outs, fill=True, color="blue")
plt.axvline(x = np.mean(train_outs), color = 'r')
plt.axvline(x = np.mean(test_outs), color = 'blue')
plt.xlabel('output value')

print('avg acc ', np.mean(res4[2][-1,:]))
print('diff ', np.mean(test_outs) - np.mean(train_outs))
# Out:
# avg acc  0.9829545454545454
# diff  0.13333333333333286

# %%
# Out:
# avg acc  0.9829545454545454

# %%
#exp2 - 5 train inps ########## TEST: A

p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+'], ['F','B','C', 'D', 'E'], len_seq = 1, init_values = ['F','B', 'C',  'D', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

res5_A = exp1(p, trainseqs, testseqs)
# Out:
# trial
# ['A', ('+', 'B'), 5]    1.0000
# ['A', ('+', 'C'), 7]    1.0000
# ['A', ('+', 'D'), 9]    1.0000
# ['A', ('+', 'E'), 3]    1.0000
# ['A', ('+', 'F'), 6]    1.0000
# ['A', ('+', 'A'), 4]    0.0625
# ['B', ('+', 'A'), 5]    0.0000
# ['C', ('+', 'A'), 7]    0.0000
# ['D', ('+', 'A'), 9]    0.0000
# ['E', ('+', 'A'), 3]    0.0000
# ['F', ('+', 'A'), 6]    0.0000
# dtype: float64
# time:  2.2370436350504557

# %%
trainseqs = generate_sequences(['+'], ['F','B','C', 'D', 'E'], len_seq = 1, init_values = ['F','B', 'C',  'D', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

train_outs = [seq[-1] for seq in trainseqs]
test_outs = [seq[-1] for seq in testseqs]

sns.kdeplot(train_outs, fill=True, color="r")
sns.kdeplot(test_outs, fill=True, color="blue")
plt.axvline(x = np.mean(train_outs), color = 'r')
plt.axvline(x = np.mean(test_outs), color = 'blue')
plt.xlabel('output value')

print('avg acc ', np.mean(res5_A[2][-1,:]))
print('diff ', np.mean(test_outs) - np.mean(train_outs))
# Out:
# avg acc  0.4602272727272727
# diff  -0.666666666666667

# %%
#exp2 - 5 train inps ########## TEST: B

p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+'], ['A','F','C', 'D', 'E'], len_seq = 1, init_values = ['A','F', 'C',  'D', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

res5 = exp1(p, trainseqs, testseqs)
# Out:
# trial
# ['B', ('+', 'A'), 5]     1.0000
# ['B', ('+', 'C'), 8]     1.0000
# ['B', ('+', 'D'), 10]    1.0000
# ['B', ('+', 'E'), 4]     1.0000
# ['B', ('+', 'F'), 7]     1.0000
# ['B', ('+', 'B'), 6]     0.4375
# ['A', ('+', 'B'), 5]     0.3750
# ['E', ('+', 'B'), 4]     0.3750
# ['C', ('+', 'B'), 8]     0.3125
# ['D', ('+', 'B'), 10]    0.3125
# ['F', ('+', 'B'), 7]     0.3125
# dtype: float64
# time:  2.393979243437449

# %%
res5[1].shape
# Out:
# (1000, 8)

# %%
trainseqs = generate_sequences(['+'], ['A','F','C', 'D', 'E'], len_seq = 1, init_values = ['A','F', 'C',  'D', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

train_outs = [seq[-1] for seq in trainseqs]
test_outs = [seq[-1] for seq in testseqs]

sns.kdeplot(train_outs, fill=True, color="r")
sns.kdeplot(test_outs, fill=True, color="blue")
plt.axvline(x = np.mean(train_outs), color = 'r')
plt.axvline(x = np.mean(test_outs), color = 'blue')
plt.xlabel('output value')

print('avg acc ', np.mean(res5[2][-1,:]))
print('diff ', np.mean(test_outs) - np.mean(train_outs))
# Out:
# avg acc  0.6477272727272727
# diff  -0.2666666666666666

# %%
#exp2 - 5 train inps ########## TEST: C

p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+'], ['A','B','F', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'F',  'D', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

res6 = exp1(p, trainseqs, testseqs)
# Out:
# trial
# ['C', ('+', 'A'), 7]     1.0000
# ['C', ('+', 'B'), 8]     1.0000
# ['C', ('+', 'D'), 12]    1.0000
# ['C', ('+', 'E'), 6]     1.0000
# ['C', ('+', 'F'), 9]     1.0000
# ['A', ('+', 'C'), 7]     0.6250
# ['B', ('+', 'C'), 8]     0.6250
# ['E', ('+', 'C'), 6]     0.6250
# ['F', ('+', 'C'), 9]     0.6250
# ['D', ('+', 'C'), 12]    0.5625
# ['C', ('+', 'C'), 10]    0.4375
# dtype: float64
# time:  2.136817967891693

# %%
trainseqs = generate_sequences(['+'], ['A','B','F', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'F',  'D', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

train_outs = [seq[-1] for seq in trainseqs]
test_outs = [seq[-1] for seq in testseqs]

sns.kdeplot(train_outs, fill=True, color="r")
sns.kdeplot(test_outs, fill=True, color="blue")
plt.axvline(x = np.mean(train_outs), color = 'r')
plt.axvline(x = np.mean(test_outs), color = 'blue')
plt.xlabel('output value')

print('avg acc ', np.mean(res6[2][-1,:]))
print('diff ', np.mean(test_outs) - np.mean(train_outs))
# Out:
# avg acc  0.7727272727272727
# diff  0.5333333333333332

# %%
#exp2 - 5 train inps ########## TEST: D

p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+'], ['A','B','C', 'F', 'E'], len_seq = 1, init_values = ['A','B', 'C','F', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

res7 = exp1(p, trainseqs, testseqs)
# Out:
# trial
# ['D', ('+', 'A'), 9]     0.9375
# ['D', ('+', 'B'), 10]    0.9375
# ['D', ('+', 'C'), 12]    0.9375
# ['D', ('+', 'E'), 8]     0.9375
# ['D', ('+', 'F'), 11]    0.9375
# ['A', ('+', 'D'), 9]     0.0000
# ['B', ('+', 'D'), 10]    0.0000
# ['C', ('+', 'D'), 12]    0.0000
# ['D', ('+', 'D'), 14]    0.0000
# ['E', ('+', 'D'), 8]     0.0000
# ['F', ('+', 'D'), 11]    0.0000
# dtype: float64
# time:  3.5117459972699483

# %%
trainseqs = generate_sequences(['+'], ['A','B','C', 'F', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'F', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

train_outs = [seq[-1] for seq in trainseqs]
test_outs = [seq[-1] for seq in testseqs]

sns.kdeplot(train_outs, fill=True, color="r")
sns.kdeplot(test_outs, fill=True, color="blue")
plt.axvline(x = np.mean(train_outs), color = 'r')
plt.axvline(x = np.mean(test_outs), color = 'blue')
plt.xlabel('output value')

print('avg acc ', np.mean(res7[2][-1,:]))
print('diff ', np.mean(test_outs) - np.mean(train_outs))
# Out:
# avg acc  0.42613636363636365
# diff  1.333333333333333

# %%
#exp2 - 5 train inps ########## TEST: E

p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+'], ['A','B','C', 'D', 'F'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'F'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

res8 = exp1(p, trainseqs, testseqs)
# Out:
# trial
# ['E', ('+', 'A'), 3]    0.8125
# ['E', ('+', 'B'), 4]    0.8125
# ['E', ('+', 'C'), 6]    0.6875
# ['E', ('+', 'F'), 5]    0.6250
# ['E', ('+', 'D'), 8]    0.5625
# ['A', ('+', 'E'), 3]    0.0000
# ['B', ('+', 'E'), 4]    0.0000
# ['C', ('+', 'E'), 6]    0.0000
# ['D', ('+', 'E'), 8]    0.0000
# ['E', ('+', 'E'), 2]    0.0000
# ['F', ('+', 'E'), 5]    0.0000
# dtype: float64
# time:  2.976121970017751
# ########## rep 0 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 1 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 4 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.1
# ########## rep 5 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 6 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.6
# ########## rep 3 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.1
# ########## rep 7 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.0
# ########## rep 2 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 2.2

# %%
trainseqs = generate_sequences(['+'], ['A','B','C', 'D', 'F'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'F'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

train_outs = [seq[-1] for seq in trainseqs]
test_outs = [seq[-1] for seq in testseqs]

sns.kdeplot(train_outs, fill=True, color="r")
sns.kdeplot(test_outs, fill=True, color="blue")
plt.axvline(x = np.mean(train_outs), color = 'r')
plt.axvline(x = np.mean(test_outs), color = 'blue')
plt.xlabel('output value')
print('avg acc ', np.mean(res8[2][-1,:]))
print('diff ', np.mean(test_outs) - np.mean(train_outs))
# Out:
# avg acc  0.3181818181818182
# diff  -1.0666666666666673

# %%
# plot output dists

# %%
acc_vals = [0.46, 0.65, 0.77, 0.43, 0.32, 0.98]
#diffs = [0.17, 0.49, 1.14, 1.33, 0.15, 0.82]
diffs = [0.67, 0.27, 0.53, 1.33, 1.07, 0.13]
labs = ['A', 'B', 'C', 'D', 'E', 'F']

# %%
plt.scatter(diffs, acc_vals)
for i, txt in enumerate(labs):
    plt.annotate(txt, (diffs[i], acc_vals[i] ), fontsize = 20)
    
plt.xlabel('mean test output - mean train output')
plt.ylabel('average test accuracy')
# Out:
# Text(0, 0.5, 'average test accuracy')

# %%
p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'E']) + p
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

train_outs = [seq[-1] for seq in trainseqs]
test_outs = [seq[-1] for seq in testseqs]

sns.kdeplot(train_outs, fill=True, color="r", label = 'train_output')
sns.kdeplot(test_outs, fill=True, color="blue", label = 'test_output')
plt.axvline(x = np.mean(train_outs), color = 'r')
plt.axvline(x = np.mean(test_outs), color = 'blue')
plt.xlabel('output value')
plt.legend()

print('diff ', np.mean(test_outs) - np.mean(train_outs))
# Out:
# diff  0.8172043010752681

# %%
p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'E'])
testseqs = generate_sequences(['+'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

train_outs = [seq[-1] for seq in trainseqs]
test_outs = [seq[-1] for seq in testseqs]

print('diff ', np.mean(test_outs) - np.mean(train_outs))
# Out:
# diff  0.13333333333333286

# %%
diffs = [0.17, 0.49, 1.14, 1.33, 0.15, 0.82]

# %%
#exp2 - 5 train inps ########## TEST: F
epochs = 1000
p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['-'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'E'])
testseqs = generate_sequences(['-'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

res4 = exp1(p, trainseqs, testseqs)
plt.title('Subtraction')
# Out:
# trial
# ['F', ('-', 'A'), 2]     1.0000
# ['F', ('-', 'B'), 1]     1.0000
# ['F', ('-', 'C'), -1]    1.0000
# ['F', ('-', 'D'), -3]    1.0000
# ['F', ('-', 'E'), 3]     1.0000
# ['E', ('-', 'F'), -3]    0.9375
# ['A', ('-', 'F'), -2]    0.8750
# ['B', ('-', 'F'), -1]    0.8750
# ['C', ('-', 'F'), 1]     0.8125
# ['F', ('-', 'F'), 0]     0.8125
# ['D', ('-', 'F'), 3]     0.6875
# dtype: float64
# time:  2.193291250864665
# Text(0.5, 1.0, 'Subtraction')

# %%
#exp2 - 5 train inps ########## TEST: F
epochs = 1000
p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['*'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'E'])
testseqs = generate_sequences(['*'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

res4 = exp1(p, trainseqs, testseqs)
plt.title('multiplication')
# Out:
# trial
# ['F', ('*', 'E'), 4]     0.7500
# ['F', ('*', 'B'), 12]    0.5625
# ['E', ('*', 'F'), 4]     0.4375
# ['F', ('*', 'A'), 8]     0.3750
# ['A', ('*', 'F'), 8]     0.2500
# ['F', ('*', 'C'), 20]    0.1250
# ['F', ('*', 'D'), 28]    0.1250
# ['B', ('*', 'F'), 12]    0.0625
# ['C', ('*', 'F'), 20]    0.0000
# ['D', ('*', 'F'), 28]    0.0000
# ['F', ('*', 'F'), 16]    0.0000
# dtype: float64
# time:  2.152975849310557
# Text(0.5, 1.0, 'multiplication')
# ########## rep 4 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.7
# ########## rep 0 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 1.2
# ########## rep 7 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.1
# ########## rep 5 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 77.5
# ########## rep 0 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.7
# ########## rep 5 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 36.0
# ########## rep 1 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.4
# ########## rep 4 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 1.6
# ########## rep 3 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.9
# ########## rep 1 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 16.7
# ########## rep 0 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.3
# ########## rep 2 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 14.4
# ########## rep 6 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.1
# ########## rep 3 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 5.3
# ########## rep 4 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.7
# ########## rep 7 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 6.4
# ########## rep 7 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.3
# ########## rep 7 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.7
# ########## rep 6 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.3
# ########## rep 0 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 1.3
# ########## rep 5 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 1.0
# ########## rep 2 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 20.2
# ########## rep 5 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.1
# ########## rep 3 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 3.1
# ########## rep 1 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.2
# ########## rep 6 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.9
# ########## rep 3 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.1
# ########## rep 1 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 1.8
# ########## rep 2 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 0.6
# ########## rep 4 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 2.6
# ########## rep 2 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 1.1
# ########## rep 6 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# loss: 1.0

# %% [markdown]
# # Multiple ops

# %%
#exp2 - 5 train inps ########## TEST: F
epochs = 2500
p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+','-'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'E'])
testseqs = generate_sequences(['+','-'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])

res2ops = exp1(p, trainseqs, testseqs)
# Out:
# trial
# ['F', ('+', 'B'), 7]     1.0000
# ['F', ('+', 'A'), 6]     1.0000
# ['F', ('+', 'D'), 11]    1.0000
# ['F', ('+', 'C'), 9]     0.9375
# ['F', ('+', 'E'), 5]     0.8750
# ['F', ('-', 'D'), -3]    0.7500
# ['F', ('-', 'B'), 1]     0.7500
# ['F', ('-', 'E'), 3]     0.7500
# ['F', ('-', 'C'), -1]    0.6875
# ['F', ('-', 'A'), 2]     0.6875
# ['A', ('-', 'F'), -2]    0.6250
# ['B', ('-', 'F'), -1]    0.6250
# ['E', ('-', 'F'), -3]    0.6250
# ['D', ('-', 'F'), 3]     0.5625
# ['C', ('-', 'F'), 1]     0.5625
# ['E', ('+', 'F'), 5]     0.5000
# ['D', ('+', 'F'), 11]    0.5000
# ['C', ('+', 'F'), 9]     0.5000
# ['A', ('+', 'F'), 6]     0.4375
# ['F', ('+', 'F'), 8]     0.4375
# ['B', ('+', 'F'), 7]     0.4375
# ['F', ('-', 'F'), 0]     0.4375
# dtype: float64
# time:  10.302771870295206
# ########## rep 0 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# epoch:  1000
# epoch:  1100
# epoch:  1200
# epoch:  1300
# epoch:  1400
# epoch:  1500
# epoch:  1600
# epoch:  1700
# epoch:  1800
# epoch:  1900
# epoch:  2000
# epoch:  2100
# epoch:  2200
# epoch:  2300
# epoch:  2400
# loss: 0.6
# ########## rep 5 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# epoch:  1000
# epoch:  1100
# epoch:  1200
# epoch:  1300
# epoch:  1400
# epoch:  1500
# epoch:  1600
# epoch:  1700
# epoch:  1800
# epoch:  1900
# epoch:  2000
# epoch:  2100
# epoch:  2200
# epoch:  2300
# epoch:  2400
# loss: 0.5
# ########## rep 2 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# epoch:  1000
# epoch:  1100
# epoch:  1200
# epoch:  1300
# epoch:  1400
# epoch:  1500
# epoch:  1600
# epoch:  1700
# epoch:  1800
# epoch:  1900
# epoch:  2000
# epoch:  2100
# epoch:  2200
# epoch:  2300
# epoch:  2400
# loss: 1.5
# ########## rep 1 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# epoch:  1000
# epoch:  1100
# epoch:  1200
# epoch:  1300
# epoch:  1400
# epoch:  1500
# epoch:  1600
# epoch:  1700
# epoch:  1800
# epoch:  1900
# epoch:  2000
# epoch:  2100
# epoch:  2200
# epoch:  2300
# epoch:  2400
# loss: 0.8
# ########## rep 4 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# epoch:  1000
# epoch:  1100
# epoch:  1200
# epoch:  1300
# epoch:  1400
# epoch:  1500
# epoch:  1600
# epoch:  1700
# epoch:  1800
# epoch:  1900
# epoch:  2000
# epoch:  2100
# epoch:  2200
# epoch:  2300
# epoch:  2400
# loss: 0.1
# ########## rep 3 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# epoch:  1000
# epoch:  1100
# epoch:  1200
# epoch:  1300
# epoch:  1400
# epoch:  1500
# epoch:  1600
# epoch:  1700
# epoch:  1800
# epoch:  1900
# epoch:  2000
# epoch:  2100
# epoch:  2200
# epoch:  2300
# epoch:  2400
# loss: 3.5
# ########## rep 7 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# epoch:  1000
# epoch:  1100
# epoch:  1200
# epoch:  1300
# epoch:  1400
# epoch:  1500
# epoch:  1600
# epoch:  1700
# epoch:  1800
# epoch:  1900
# epoch:  2000
# epoch:  2100
# epoch:  2200
# epoch:  2300
# epoch:  2400
# loss: 0.1
# ########## rep 6 #########
# epoch:  0
# epoch:  100
# epoch:  200
# epoch:  300
# epoch:  400
# epoch:  500
# epoch:  600
# epoch:  700
# epoch:  800
# epoch:  900
# epoch:  1000
# epoch:  1100
# epoch:  1200
# epoch:  1300
# epoch:  1400
# epoch:  1500
# epoch:  1600
# epoch:  1700
# epoch:  1800
# epoch:  1900
# epoch:  2000
# epoch:  2100
# epoch:  2200
# epoch:  2300
# epoch:  2400
# loss: 2.8

# %%
p = [['A', ('X','X'), ('X','X'), 2],\
     ['C', ('X','X'), ('X','X'), 5],\
     ['B', ('X','X'), ('X','X'), 3],\
     ['D', ('X','X'), ('X','X'), 7],\
     ['E', ('X','X'), ('X','X'), 1],\
     ['F', ('X','X'), ('X','X'), 4]
    ]

trainseqs = generate_sequences(['+','-'], ['A','B','C', 'D', 'E'], len_seq = 1, init_values = ['A','B', 'C',  'D', 'E'])
testseqs = generate_sequences(['+','-'], ['A','B','C', 'D', 'E', 'F'], len_seq = 1, init_values = ['A','B','C', 'D', 'E', 'F'])


train_outs = [seq[-1] for seq in trainseqs]
test_outs = [seq[-1] for seq in testseqs]

sns.kdeplot(train_outs, fill=True, color="r", label = 'train_output')
sns.kdeplot(test_outs, fill=True, color="blue", label = 'test_output')
plt.axvline(x = np.mean(train_outs), color = 'r')
plt.axvline(x = np.mean(test_outs), color = 'blue')
plt.xlabel('output value')
plt.legend()

print('diff ', np.mean(test_outs) - np.mean(train_outs))
# Out:
# diff  0.06666666666666643

# %%
#train 2 on + and 2 on -, then switch
